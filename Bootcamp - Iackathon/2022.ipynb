# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2022

# %%
datasa_2022=["awards_2022.csv","contracts_2022.csv","extensions_2022.csv","metadata_2022.csv","planning_2022.csv","releases_2022.csv","suppliers_2022.csv","tender_2022.csv"]
datas_dir ="assets/data/releases_2022/"
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### awards_2022.csv

# %%
awards_2022_df = pd.read_csv(os.path.join(datas_dir,datasa_2022[0]),sep=",")
awards_2022_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_68670/65761889.py:1: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   awards_2022_df = pd.read_csv(os.path.join(datas_dir,datasa_2022[0]),sep=",")
#                                       ocid
# 0  ocds-5wno2w-MCO-EPMAPS-GT32-2022-258814  \
# 1   ocds-5wno2w-MCO-MAATE-005-2022-1007399
# 2     ocds-5wno2w-SIE-GADMC-021-2022-35903
# 3       ocds-5wno2w-CE-20220002238648-3214
# 4       ocds-5wno2w-CE-20220002238650-3214
# 5       ocds-5wno2w-CE-20220002238655-3214
# 6     ocds-5wno2w-CE-20220002126850-533065
# 7     ocds-5wno2w-CE-20220002126851-533065
# 8     ocds-5wno2w-CE-20220002126852-533065
# 9     ocds-5wno2w-CE-20220002126853-533065
#
#                                           release_id
# 0  MCO-EPMAPS-GT32-2022-258814-2023-02-11T11:00:2...  \
# 1  MCO-MAATE-005-2022-1007399-2023-02-11T10:52:12...
# 2  SIE-GADMC-021-2022-35903-2023-02-11T10:59:17.6...
# ...

# %%
#Columnas 
awards_2022_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status', 'date',
#        'amount', 'currency', 'correctedValue_amount',
#        'correctedValue_currency', 'enteredValue_amount',
#        'enteredValue_currency', 'contractPeriod_startDate',
#        'contractPeriod_endDate', 'contractPeriod_maxExtentDate',
#        'contractPeriod_durationInDays'],
#       dtype='object')

# %%
awards_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182740 entries, 0 to 182739
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           182740 non-null  object
#  1   release_id                     182740 non-null  object
#  2   id                             182740 non-null  object
#  3   title                          0 non-null       float64
#  4   description                    46145 non-null   object
#  5   status                         132467 non-null  object
#  6   date                           36374 non-null   object
#  7   amount                         182734 non-null  float64
#  8   currency                       182734 non-null  object
#  9   correctedValue_amount          0 non-null       float64
#  10  correctedValue_currency        0 non-null       float64
#  11  enteredValue_amount            0 non-null       float64
# ...

# %% [markdown]
# ### contracts_2022.csv

# %%
contracts_2022_df = pd.read_csv(os.path.join(datas_dir,datasa_2022[1]),sep=",")
contracts_2022_df.head(10)
# Out:
#                                      ocid
# 0  ocds-5wno2w-MCO-MAATE-005-2022-1007399  \
# 1      ocds-5wno2w-CE-20220002238648-3214
# 2      ocds-5wno2w-CE-20220002238650-3214
# 3      ocds-5wno2w-CE-20220002238655-3214
# 4    ocds-5wno2w-CE-20220002126850-533065
# 5    ocds-5wno2w-CE-20220002126851-533065
# 6    ocds-5wno2w-CE-20220002126852-533065
# 7    ocds-5wno2w-CE-20220002126853-533065
# 8    ocds-5wno2w-CE-20220002126854-533065
# 9    ocds-5wno2w-CE-20220002131144-116599
#
#                                           release_id
# 0  MCO-MAATE-005-2022-1007399-2023-02-11T10:52:12...  \
# 1    CE-20220002238648-3214-2023-02-13T08:02:37.344Z
# 2    CE-20220002238650-3214-2023-02-13T08:02:37.557Z
# 3    CE-20220002238655-3214-2023-02-13T08:02:38.315Z
# 4  CE-20220002126850-533065-2023-02-14T04:18:58.226Z
# 5  CE-20220002126851-533065-2023-02-14T04:18:58.247Z
# 6  CE-20220002126852-533065-2023-02-14T04:18:58.262Z
# 7  CE-20220002126853-533065-2023-02-14T04:18:58.278Z
# ...

# %%
#Columnas
contracts_2022_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171301 entries, 0 to 171300
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           171301 non-null  object
#  1   release_id                     171301 non-null  object
#  2   id                             171301 non-null  object
#  3   awardID                        171301 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         171301 non-null  object
#  7   contractPeriod_startDate       34706 non-null   object
#  8   contractPeriod_endDate         34706 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  34700 non-null   float64
#  11  amount                         34706 non-null   float64
# ...

# %% [markdown]
# ### extensions_2022.csv

# %%
extensions_2022_df = pd.read_csv(os.path.join(datas_dir,datasa_2022[2]),sep=",")
extensions_2022_df.head(10)
# Out:
#                                            extension
# 0  https://raw.githubusercontent.com/open-contrac...
# 1  https://raw.githubusercontent.com/open-contrac...
# 2  https://raw.githubusercontent.com/open-contrac...
# 3  https://raw.githubusercontent.com/GobiernoFaci...
# 4  https://gitlab.com/dncp-opendata/ocds_auctions...
# 5  https://raw.githubusercontent.com/open-contrac...
# 6  https://raw.githubusercontent.com/open-contrac...

# %%
#Columnas
contracts_2022_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171301 entries, 0 to 171300
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           171301 non-null  object
#  1   release_id                     171301 non-null  object
#  2   id                             171301 non-null  object
#  3   awardID                        171301 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         171301 non-null  object
#  7   contractPeriod_startDate       34706 non-null   object
#  8   contractPeriod_endDate         34706 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  34700 non-null   float64
#  11  amount                         34706 non-null   float64
# ...

# %% [markdown]
# ### metadata_2022.csv

# %%
metadata_2022_df = pd.read_csv(os.path.join(datas_dir,datasa_2022[3]),sep=",")
metadata_2022_df.head(10)
# Out:
#                                                  Uri  Version
# 0  https://portal.compraspublicas.gob.ec/sercop/d...      1.1  \
#
#                                        PublisherName PublisherScheme
# 0  Servicio Nacional de Contratación Pública (SER...            OCDS  \
#
#   PublisherUid                        PublisherUri
# 0  ocds-5wno2w  https://www.compraspublicas.gob.ec  \
#
#                                            License
# 0  https://creativecommons.org/licenses/by/3.0/ec/  \
#
#                                    PublicationPolicy             PublishedDate
# 0  https://datosabiertos.compraspublicas.gob.ec/P...  2023-03-02T11:03:34.662Z

# %%
#Columnas
metadata_2022_df.columns
# Out:
# Index(['Uri', 'Version', 'PublisherName', 'PublisherScheme', 'PublisherUid',
#        'PublisherUri', 'License', 'PublicationPolicy', 'PublishedDate'],
#       dtype='object')

# %% [markdown]
# ### planning_2022.csv

# %%
planning_2022_df = pd.read_csv(os.path.join(datas_dir,datasa_2022[4]),sep=",")
planning_2022_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-MCO-EPMAPS-GT32-2022-258814  \
# 1   ocds-5wno2w-MCO-MAATE-005-2022-1007399
# 2    ocds-5wno2w-MCS-GADMCQ-009-2022-36121
# 3     ocds-5wno2w-SIE-GADMC-021-2022-35903
# 4  ocds-5wno2w-COTS-CNELMAN-20-2022-462114
# 5       ocds-5wno2w-LICO-GADC-06-2022-2616
# 6       ocds-5wno2w-LICO-GADC-05-2022-2616
# 7   ocds-5wno2w-CDC-GADMCLL-005-2022-35945
# 8     ocds-5wno2w-LCC-CNT-6168-2022-236009
# 9        ocds-5wno2w-MCB-GADPP-7-2022-2426
#
#                                                   id
# 0  MCO-EPMAPS-GT32-2022-258814-2023-02-11T11:00:2...  \
# 1  MCO-MAATE-005-2022-1007399-2023-02-11T10:52:12...
# 2  MCS-GADMCQ-009-2022-36121-2023-02-11T11:01:44....
# 3  SIE-GADMC-021-2022-35903-2023-02-11T10:59:17.6...
# 4  COTS-CNELMAN-20-2022-462114-2023-02-14T10:51:3...
# 5  LICO-GADC-06-2022-2616-2023-02-23T11:09:28.305...
# 6  LICO-GADC-05-2022-2616-2023-03-01T11:44:39.602...
# 7  CDC-GADMCLL-005-2022-35945-2023-02-15T10:39:37...
# ...

# %%
#Columnas
planning_2022_df.columns
# Out:
# Index(['ocid', 'id', 'rationale', 'budget_id', 'budget_description',
#        'budget_amount', 'budget_currency'],
#       dtype='object')

# %%
planning_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58861 entries, 0 to 58860
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ocid                58861 non-null  object
#  1   id                  58861 non-null  object
#  2   rationale           58861 non-null  object
#  3   budget_id           58861 non-null  object
#  4   budget_description  0 non-null      float64
#  5   budget_amount       28443 non-null  float64
#  6   budget_currency     28443 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 3.1+ MB

# %% [markdown]
# ### releases_2022.csv

# %%
releases_2022_df = pd.read_csv(os.path.join(datas_dir,datasa_2022[5]),sep=",")
releases_2022_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-MCO-EPMAPS-GT32-2022-258814  \
# 1   ocds-5wno2w-MCO-MAATE-005-2022-1007399
# 2    ocds-5wno2w-MCS-GADMCQ-009-2022-36121
# 3     ocds-5wno2w-SIE-GADMC-021-2022-35903
# 4       ocds-5wno2w-CE-20220002238648-3214
# 5       ocds-5wno2w-CE-20220002238650-3214
# 6       ocds-5wno2w-CE-20220002238655-3214
# 7     ocds-5wno2w-CE-20220002126850-533065
# 8     ocds-5wno2w-CE-20220002126851-533065
# 9     ocds-5wno2w-CE-20220002126852-533065
#
#                                                   id initiationType
# 0  MCO-EPMAPS-GT32-2022-258814-2023-02-11T11:00:2...         tender  \
# 1  MCO-MAATE-005-2022-1007399-2023-02-11T10:52:12...         tender
# 2  MCS-GADMCQ-009-2022-36121-2023-02-11T11:01:44....         tender
# 3  SIE-GADMC-021-2022-35903-2023-02-11T10:59:17.6...         tender
# 4    CE-20220002238648-3214-2023-02-13T08:02:37.344Z         tender
# 5    CE-20220002238650-3214-2023-02-13T08:02:37.557Z         tender
# ...

# %%
#Columnas
releases_2022_df.columns
# Out:
# Index(['ocid', 'id', 'initiationType', 'buyer_id', 'buyer_name', 'language',
#        'date', 'tag'],
#       dtype='object')

# %%
releases_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195456 entries, 0 to 195455
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ocid            195456 non-null  object
#  1   id              195456 non-null  object
#  2   initiationType  195456 non-null  object
#  3   buyer_id        195456 non-null  object
#  4   buyer_name      195456 non-null  object
#  5   language        195456 non-null  object
#  6   date            195456 non-null  object
#  7   tag             195456 non-null  object
# dtypes: object(8)
# memory usage: 11.9+ MB

# %% [markdown]
# ### suppliers_2022.csv

# %%
suppliers_2022_df = pd.read_csv(os.path.join(datas_dir,datasa_2022[6]),sep=",")
suppliers_2022_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-MCO-EPMAPS-GT32-2022-258814  \
# 1   ocds-5wno2w-MCO-MAATE-005-2022-1007399
# 2     ocds-5wno2w-SIE-GADMC-021-2022-35903
# 3       ocds-5wno2w-CE-20220002238648-3214
# 4       ocds-5wno2w-CE-20220002238650-3214
# 5       ocds-5wno2w-CE-20220002238655-3214
# 6     ocds-5wno2w-CE-20220002126850-533065
# 7     ocds-5wno2w-CE-20220002126851-533065
# 8     ocds-5wno2w-CE-20220002126852-533065
# 9     ocds-5wno2w-CE-20220002126853-533065
#
#                                           release_id
# 0  MCO-EPMAPS-GT32-2022-258814-2023-02-11T11:00:2...  \
# 1  MCO-MAATE-005-2022-1007399-2023-02-11T10:52:12...
# 2  SIE-GADMC-021-2022-35903-2023-02-11T10:59:17.6...
# 3    CE-20220002238648-3214-2023-02-13T08:02:37.344Z
# 4    CE-20220002238650-3214-2023-02-13T08:02:37.557Z
# 5    CE-20220002238655-3214-2023-02-13T08:02:38.315Z
# 6  CE-20220002126850-533065-2023-02-14T04:18:58.226Z
# 7  CE-20220002126851-533065-2023-02-14T04:18:58.247Z
# ...

# %%
#Columnas
suppliers_2022_df.columns
# Out:
# Index(['ocid', 'release_id', 'award_id', 'id', 'name'], dtype='object')

# %%
suppliers_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182740 entries, 0 to 182739
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ocid        182740 non-null  object
#  1   release_id  182740 non-null  object
#  2   award_id    182740 non-null  object
#  3   id          182740 non-null  object
#  4   name        182728 non-null  object
# dtypes: object(5)
# memory usage: 7.0+ MB

# %% [markdown]
# ### tender_2022.csv

# %%
tender_2022_df = pd.read_csv(os.path.join(datas_dir,datasa_2022[7]),sep=",")
tender_2022_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-MCO-EPMAPS-GT32-2022-258814  \
# 1   ocds-5wno2w-MCO-MAATE-005-2022-1007399
# 2     ocds-5wno2w-SIE-GADMC-021-2022-35903
# 3       ocds-5wno2w-CE-20220002238648-3214
# 4       ocds-5wno2w-CE-20220002238650-3214
# 5       ocds-5wno2w-CE-20220002238655-3214
# 6     ocds-5wno2w-CE-20220002126850-533065
# 7     ocds-5wno2w-CE-20220002126851-533065
# 8     ocds-5wno2w-CE-20220002126852-533065
# 9     ocds-5wno2w-CE-20220002126853-533065
#
#                                           release_id
# 0  MCO-EPMAPS-GT32-2022-258814-2023-02-11T11:00:2...  \
# 1  MCO-MAATE-005-2022-1007399-2023-02-11T10:52:12...
# 2  SIE-GADMC-021-2022-35903-2023-02-11T10:59:17.6...
# 3    CE-20220002238648-3214-2023-02-13T08:02:37.344Z
# 4    CE-20220002238650-3214-2023-02-13T08:02:37.557Z
# 5    CE-20220002238655-3214-2023-02-13T08:02:38.315Z
# 6  CE-20220002126850-533065-2023-02-14T04:18:58.226Z
# 7  CE-20220002126851-533065-2023-02-14T04:18:58.247Z
# ...

# %%
#Columnas
tender_2022_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status',
#        'procuringEntity_id', 'procuringEntity_name', 'value_amount',
#        'value_currency', 'procurementMethod', 'procurementMethodDetails',
#        'mainProcurementCategory', 'awardCriteria', 'tenderPeriod_startDate',
#        'tenderPeriod_endDate', 'tenderPeriod_maxExtentDate',
#        'tenderPeriod_durationInDays', 'enquiryPeriod_startDate',
#        'enquiryPeriod_endDate', 'enquiryPeriod_maxExtentDate',
#        'enquiryPeriod_durationInDays', 'hasEnquiries', 'eligibilityCriteria',
#        'awardPeriod_startDate', 'awardPeriod_endDate',
#        'awardPeriod_maxExtentDate', 'awardPeriod_durationInDays',
#        'numberOfTenderers'],
#       dtype='object')

# %%
tender_2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186059 entries, 0 to 186058
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ocid                          186059 non-null  object
#  1   release_id                    186059 non-null  object
#  2   id                            186059 non-null  object
#  3   title                         186059 non-null  object
#  4   description                   186059 non-null  object
#  5   status                        186059 non-null  object
#  6   procuringEntity_id            186032 non-null  object
#  7   procuringEntity_name          186032 non-null  object
#  8   value_amount                  159735 non-null  float64
#  9   value_currency                159735 non-null  object
#  10  procurementMethod             186059 non-null  object
#  11  procurementMethodDetails      186059 non-null  object
# ...
