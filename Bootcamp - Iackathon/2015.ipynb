# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2015

# %%
datasa_2015=["awards_2015.csv","contracts_2015.csv","extensions_2015.csv","metadata_2015.csv","planning_2015.csv","releases_2015.csv","suppliers_2015.csv","tender_2015.csv"]
datas_dir ="assets/data/releases_2015/"
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### awards_2015.csv

# %%
awards_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[0]),sep=",")
awards_2015_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_65341/3702768002.py:1: DtypeWarning: Columns (4,5,6,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   awards_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[0]),sep=",")
#                                       ocid
# 0      ocds-5wno2w-MCO-ML-GOP-44-2015-2423  \
# 1  ocds-5wno2w-COTO-GADMEA-012-2015-175195
# 2       ocds-5wno2w-MCO-GMCM-028-2015-2689
# 3     ocds-5wno2w-COTO-GAD-I-009-2015-2783
# 4    ocds-5wno2w-COTO-GAD-I-010A-2015-2783
# 5     ocds-5wno2w-MCBS-GA-1-025-2015-15414
# 6   ocds-5wno2w-MCO-GADM-CG-009-2015-79844
# 7      ocds-5wno2w-MCO-GADMCM-13-2015-2742
# 8   ocds-5wno2w-MCO-GADMSL-010-2015-100696
# 9      ocds-5wno2w-RE-2662-ZNO-E-15-253178
#
#                                           release_id
# 0   MCO-ML-GOP-44-2015-2423-2021-12-03T00:34:30.539Z  \
# 1  COTO-GADMEA-012-2015-175195-2021-12-03T01:26:4...
# 2    MCO-GMCM-028-2015-2689-2021-12-02T21:46:52.547Z
# ...

# %%
#Columnas 
awards_2015_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status', 'date',
#        'amount', 'currency', 'correctedValue_amount',
#        'correctedValue_currency', 'enteredValue_amount',
#        'enteredValue_currency', 'contractPeriod_startDate',
#        'contractPeriod_endDate', 'contractPeriod_maxExtentDate',
#        'contractPeriod_durationInDays'],
#       dtype='object')

# %%
awards_2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284651 entries, 0 to 284650
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           284651 non-null  object
#  1   release_id                     284651 non-null  object
#  2   id                             284651 non-null  object
#  3   title                          0 non-null       float64
#  4   description                    55295 non-null   object
#  5   status                         229323 non-null  object
#  6   date                           44543 non-null   object
#  7   amount                         284648 non-null  float64
#  8   currency                       284650 non-null  object
#  9   correctedValue_amount          0 non-null       float64
#  10  correctedValue_currency        0 non-null       float64
#  11  enteredValue_amount            0 non-null       float64
# ...

# %% [markdown]
# ### contracts_2015.csv

# %%
contracts_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[1]),sep=",")
contracts_2015_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_65341/327883826.py:1: DtypeWarning: Columns (7,8,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   contracts_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[1]),sep=",")
#                                       ocid
# 0     ocds-5wno2w-MCBS-GA-1-025-2015-15414  \
# 1      ocds-5wno2w-RE-2662-ZNO-E-15-253178
# 2       ocds-5wno2w-RE-APPB-002-2015-58563
# 3      ocds-5wno2w-RE-APPB--003-2015-58563
# 4      ocds-5wno2w-RE-APPB--004-2015-58563
# 5      ocds-5wno2w-CCP-GADCM-001-2015-2896
# 6  ocds-5wno2w-CDC-CNTEP-1102695-15-236009
# 7     ocds-5wno2w-003-DPEC-CNE-2015-121514
# 8   ocds-5wno2w-004-CDC-GADPLC-2015-114590
# 9      ocds-5wno2w-31-EMASEOEP-2015-276265
#
#                                           release_id
# 0  MCBS-GA-1-025-2015-15414-2021-12-02T18:26:13.655Z  \
# 1   RE-2662-ZNO-E-15-253178-2021-12-02T18:23:45.497Z
# 2    RE-APPB-002-2015-58563-2021-12-02T17:26:57.665Z
# ...

# %%
#Columnas
contracts_2015_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272544 entries, 0 to 272543
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           272544 non-null  object
#  1   release_id                     272544 non-null  object
#  2   id                             272544 non-null  object
#  3   awardID                        272544 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         272544 non-null  object
#  7   contractPeriod_startDate       43173 non-null   object
#  8   contractPeriod_endDate         43173 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  43087 non-null   float64
#  11  amount                         43168 non-null   float64
# ...

# %% [markdown]
# ### extensions_2015.csv

# %%
extensions_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[2]),sep=",")
extensions_2015_df.head(10)
# Out:
#                                            extension
# 0  https://raw.githubusercontent.com/open-contrac...
# 1  https://raw.githubusercontent.com/open-contrac...
# 2  https://raw.githubusercontent.com/open-contrac...
# 3  https://raw.githubusercontent.com/GobiernoFaci...
# 4  https://gitlab.com/dncp-opendata/ocds_auctions...
# 5  https://raw.githubusercontent.com/open-contrac...
# 6  https://raw.githubusercontent.com/open-contrac...

# %%
#Columnas
contracts_2015_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272544 entries, 0 to 272543
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           272544 non-null  object
#  1   release_id                     272544 non-null  object
#  2   id                             272544 non-null  object
#  3   awardID                        272544 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         272544 non-null  object
#  7   contractPeriod_startDate       43173 non-null   object
#  8   contractPeriod_endDate         43173 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  43087 non-null   float64
#  11  amount                         43168 non-null   float64
# ...

# %% [markdown]
# ### metadata_2015.csv

# %%
metadata_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[3]),sep=",")
metadata_2015_df.head(10)
# Out:
#                                                  Uri  Version
# 0  https://portal.compraspublicas.gob.ec/sercop/d...      1.1  \
#
#                                        PublisherName PublisherScheme
# 0  Servicio Nacional de Contratación Pública (SER...            OCDS  \
#
#   PublisherUid                        PublisherUri
# 0  ocds-5wno2w  https://www.compraspublicas.gob.ec  \
#
#                                            License
# 0  https://creativecommons.org/licenses/by/3.0/ec/  \
#
#                                    PublicationPolicy             PublishedDate
# 0  https://datosabiertos.compraspublicas.gob.ec/P...  2021-12-03T05:39:29.183Z

# %%
#Columnas
metadata_2015_df.columns
# Out:
# Index(['Uri', 'Version', 'PublisherName', 'PublisherScheme', 'PublisherUid',
#        'PublisherUri', 'License', 'PublicationPolicy', 'PublishedDate'],
#       dtype='object')

# %% [markdown]
# ### planning_2015.csv

# %%
planning_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[4]),sep=",")
planning_2015_df.head(10)
# Out:
#                                       ocid
# 0      ocds-5wno2w-MCO-ML-GOP-44-2015-2423  \
# 1  ocds-5wno2w-COTO-GADMEA-012-2015-175195
# 2       ocds-5wno2w-MCO-GMCM-028-2015-2689
# 3     ocds-5wno2w-COTO-GAD-I-009-2015-2783
# 4    ocds-5wno2w-COTO-GAD-I-010A-2015-2783
# 5     ocds-5wno2w-MCBS-GA-1-025-2015-15414
# 6   ocds-5wno2w-MCO-GADM-CG-009-2015-79844
# 7      ocds-5wno2w-MCO-GADMCM-13-2015-2742
# 8   ocds-5wno2w-MCO-GADMSL-010-2015-100696
# 9      ocds-5wno2w-RE-2662-ZNO-E-15-253178
#
#                                                   id
# 0   MCO-ML-GOP-44-2015-2423-2021-12-03T00:34:30.539Z  \
# 1  COTO-GADMEA-012-2015-175195-2021-12-03T01:26:4...
# 2    MCO-GMCM-028-2015-2689-2021-12-02T21:46:52.547Z
# 3  COTO-GAD-I-009-2015-2783-2021-12-03T00:04:34.256Z
# 4  COTO-GAD-I-010A-2015-2783-2021-12-02T19:49:54....
# 5  MCBS-GA-1-025-2015-15414-2021-12-02T18:26:13.655Z
# 6  MCO-GADM-CG-009-2015-79844-2021-12-02T22:37:41...
# 7   MCO-GADMCM-13-2015-2742-2021-12-02T21:25:57.671Z
# ...

# %%
#Columnas
planning_2015_df.columns
# Out:
# Index(['ocid', 'id', 'rationale', 'budget_id', 'budget_description',
#        'budget_amount', 'budget_currency'],
#       dtype='object')

# %%
planning_2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51320 entries, 0 to 51319
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ocid                51320 non-null  object
#  1   id                  51320 non-null  object
#  2   rationale           51320 non-null  object
#  3   budget_id           51320 non-null  object
#  4   budget_description  0 non-null      float64
#  5   budget_amount       28636 non-null  float64
#  6   budget_currency     28636 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 2.7+ MB

# %% [markdown]
# ### releases_2015.csv

# %%
releases_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[5]),sep=",")
releases_2015_df.head(10)
# Out:
#                                       ocid
# 0      ocds-5wno2w-MCO-ML-GOP-44-2015-2423  \
# 1  ocds-5wno2w-COTO-GADMEA-012-2015-175195
# 2       ocds-5wno2w-MCO-GMCM-028-2015-2689
# 3     ocds-5wno2w-COTO-GAD-I-009-2015-2783
# 4    ocds-5wno2w-COTO-GAD-I-010A-2015-2783
# 5     ocds-5wno2w-MCBS-GA-1-025-2015-15414
# 6   ocds-5wno2w-MCO-GADM-CG-009-2015-79844
# 7      ocds-5wno2w-MCO-GADMCM-13-2015-2742
# 8   ocds-5wno2w-MCO-GADMSL-010-2015-100696
# 9      ocds-5wno2w-RE-2662-ZNO-E-15-253178
#
#                                                   id initiationType
# 0   MCO-ML-GOP-44-2015-2423-2021-12-03T00:34:30.539Z         tender  \
# 1  COTO-GADMEA-012-2015-175195-2021-12-03T01:26:4...         tender
# 2    MCO-GMCM-028-2015-2689-2021-12-02T21:46:52.547Z         tender
# 3  COTO-GAD-I-009-2015-2783-2021-12-03T00:04:34.256Z         tender
# 4  COTO-GAD-I-010A-2015-2783-2021-12-02T19:49:54....         tender
# 5  MCBS-GA-1-025-2015-15414-2021-12-02T18:26:13.655Z         tender
# ...

# %%
#Columnas
releases_2015_df.columns
# Out:
# Index(['ocid', 'id', 'initiationType', 'buyer_id', 'buyer_name', 'language',
#        'date', 'tag'],
#       dtype='object')

# %%
releases_2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280643 entries, 0 to 280642
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ocid            280643 non-null  object
#  1   id              280643 non-null  object
#  2   initiationType  280643 non-null  object
#  3   buyer_id        280643 non-null  object
#  4   buyer_name      280643 non-null  object
#  5   language        280643 non-null  object
#  6   date            280643 non-null  object
#  7   tag             280643 non-null  object
# dtypes: object(8)
# memory usage: 17.1+ MB

# %% [markdown]
# ### suppliers_2015.csv

# %%
suppliers_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[6]),sep=",")
suppliers_2015_df.head(10)
# Out:
#                                       ocid
# 0      ocds-5wno2w-MCO-ML-GOP-44-2015-2423  \
# 1  ocds-5wno2w-COTO-GADMEA-012-2015-175195
# 2       ocds-5wno2w-MCO-GMCM-028-2015-2689
# 3     ocds-5wno2w-COTO-GAD-I-009-2015-2783
# 4    ocds-5wno2w-COTO-GAD-I-010A-2015-2783
# 5     ocds-5wno2w-MCBS-GA-1-025-2015-15414
# 6   ocds-5wno2w-MCO-GADM-CG-009-2015-79844
# 7      ocds-5wno2w-MCO-GADMCM-13-2015-2742
# 8   ocds-5wno2w-MCO-GADMSL-010-2015-100696
# 9      ocds-5wno2w-RE-2662-ZNO-E-15-253178
#
#                                           release_id
# 0   MCO-ML-GOP-44-2015-2423-2021-12-03T00:34:30.539Z  \
# 1  COTO-GADMEA-012-2015-175195-2021-12-03T01:26:4...
# 2    MCO-GMCM-028-2015-2689-2021-12-02T21:46:52.547Z
# 3  COTO-GAD-I-009-2015-2783-2021-12-03T00:04:34.256Z
# 4  COTO-GAD-I-010A-2015-2783-2021-12-02T19:49:54....
# 5  MCBS-GA-1-025-2015-15414-2021-12-02T18:26:13.655Z
# 6  MCO-GADM-CG-009-2015-79844-2021-12-02T22:37:41...
# 7   MCO-GADMCM-13-2015-2742-2021-12-02T21:25:57.671Z
# ...

# %%
#Columnas
suppliers_2015_df.columns
# Out:
# Index(['ocid', 'release_id', 'award_id', 'id', 'name'], dtype='object')

# %%
suppliers_2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284651 entries, 0 to 284650
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ocid        284651 non-null  object
#  1   release_id  284651 non-null  object
#  2   award_id    284651 non-null  object
#  3   id          284651 non-null  object
#  4   name        284649 non-null  object
# dtypes: object(5)
# memory usage: 10.9+ MB

# %% [markdown]
# ### tender_2015.csv

# %%
tender_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[7]),sep=",")
tender_2015_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_65341/467891985.py:1: DtypeWarning: Columns (12,13,14,15,16,18,19,20,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   tender_2015_df = pd.read_csv(os.path.join(datas_dir,datasa_2015[7]),sep=",")
#                                       ocid
# 0      ocds-5wno2w-MCO-ML-GOP-44-2015-2423  \
# 1  ocds-5wno2w-COTO-GADMEA-012-2015-175195
# 2       ocds-5wno2w-MCO-GMCM-028-2015-2689
# 3     ocds-5wno2w-COTO-GAD-I-009-2015-2783
# 4    ocds-5wno2w-COTO-GAD-I-010A-2015-2783
# 5     ocds-5wno2w-MCBS-GA-1-025-2015-15414
# 6   ocds-5wno2w-MCO-GADM-CG-009-2015-79844
# 7      ocds-5wno2w-MCO-GADMCM-13-2015-2742
# 8   ocds-5wno2w-MCO-GADMSL-010-2015-100696
# 9      ocds-5wno2w-RE-2662-ZNO-E-15-253178
#
#                                           release_id
# 0   MCO-ML-GOP-44-2015-2423-2021-12-03T00:34:30.539Z  \
# 1  COTO-GADMEA-012-2015-175195-2021-12-03T01:26:4...
# ...

# %%
#Columnas
tender_2015_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status',
#        'procuringEntity_id', 'procuringEntity_name', 'value_amount',
#        'value_currency', 'procurementMethod', 'procurementMethodDetails',
#        'mainProcurementCategory', 'awardCriteria', 'tenderPeriod_startDate',
#        'tenderPeriod_endDate', 'tenderPeriod_maxExtentDate',
#        'tenderPeriod_durationInDays', 'enquiryPeriod_startDate',
#        'enquiryPeriod_endDate', 'enquiryPeriod_maxExtentDate',
#        'enquiryPeriod_durationInDays', 'hasEnquiries', 'eligibilityCriteria',
#        'awardPeriod_startDate', 'awardPeriod_endDate',
#        'awardPeriod_maxExtentDate', 'awardPeriod_durationInDays',
#        'numberOfTenderers'],
#       dtype='object')

# %%
tender_2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280640 entries, 0 to 280639
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ocid                          280640 non-null  object
#  1   release_id                    280640 non-null  object
#  2   id                            280640 non-null  object
#  3   title                         280640 non-null  object
#  4   description                   280640 non-null  object
#  5   status                        280640 non-null  object
#  6   procuringEntity_id            280639 non-null  object
#  7   procuringEntity_name          280639 non-null  object
#  8   value_amount                  257954 non-null  float64
#  9   value_currency                257956 non-null  object
#  10  procurementMethod             280640 non-null  object
#  11  procurementMethodDetails      280640 non-null  object
# ...
