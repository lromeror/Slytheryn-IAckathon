# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2023

# %%
datasa_2023=["awards_2023.csv","contracts_2023.csv","extensions_2023.csv","metadata_2023.csv","planning_2023.csv","releases_2023.csv","suppliers_2023.csv","tender_2023.csv"]
datas_dir ="assets/data/releases_2023/"
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### awards_2023.csv

# %%
awards_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[0]),sep=",")
awards_2023_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_15726/3852511611.py:1: DtypeWarning: Columns (4,6,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   awards_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[0]),sep=",")
#                                   ocid
# 0  ocds-5wno2w-CE-20230002374213-30375  \
# 1  ocds-5wno2w-CE-20230002374214-30375
# 2  ocds-5wno2w-CE-20230002374215-30375
# 3  ocds-5wno2w-CE-20230002374216-30375
# 4  ocds-5wno2w-CE-20230002374217-30375
# 5  ocds-5wno2w-CE-20230002374218-30375
# 6  ocds-5wno2w-CE-20230002374219-30375
# 7  ocds-5wno2w-CE-20230002374220-30375
# 8  ocds-5wno2w-CE-20230002374221-30375
# 9  ocds-5wno2w-CE-20230002374222-30375
#
#                                          release_id                 id  title
# 0  CE-20230002374213-30375-2023-08-31T01:28:26.479Z  CE-20230002374213    NaN  \
# 1  CE-20230002374214-30375-2023-08-31T01:28:26.493Z  CE-20230002374214    NaN
# 2  CE-20230002374215-30375-2023-08-31T01:28:26.507Z  CE-20230002374215    NaN
# 3  CE-20230002374216-30375-2023-08-31T01:28:26.520Z  CE-20230002374216    NaN
# 4  CE-20230002374217-30375-2023-08-31T01:28:26.537Z  CE-20230002374217    NaN
# 5  CE-20230002374218-30375-2023-08-31T01:28:26.553Z  CE-20230002374218    NaN
# 6  CE-20230002374219-30375-2023-08-31T01:28:26.573Z  CE-20230002374219    NaN
# 7  CE-20230002374220-30375-2023-08-31T01:28:26.592Z  CE-20230002374220    NaN
# 8  CE-20230002374221-30375-2023-08-31T01:28:26.613Z  CE-20230002374221    NaN
# 9  CE-20230002374222-30375-2023-08-31T01:28:26.632Z  CE-20230002374222    NaN
#
#   description  status date  amount currency  correctedValue_amount
# 0         NaN  active  NaN   63.59      USD                    NaN  \
# 1         NaN  active  NaN  326.14      USD                    NaN
# 2         NaN  active  NaN  114.11      USD                    NaN
# 3         NaN  active  NaN   27.55      USD                    NaN
# 4         NaN  active  NaN   73.85      USD                    NaN
# 5         NaN  active  NaN   30.17      USD                    NaN
# 6         NaN  active  NaN   30.17      USD                    NaN
# 7         NaN  active  NaN   26.75      USD                    NaN
# 8         NaN  active  NaN   32.86      USD                    NaN
# 9         NaN  active  NaN   68.54      USD                    NaN
#
#    correctedValue_currency  enteredValue_amount  enteredValue_currency
# 0                      NaN                  NaN                    NaN  \
# 1                      NaN                  NaN                    NaN
# 2                      NaN                  NaN                    NaN
# 3                      NaN                  NaN                    NaN
# 4                      NaN                  NaN                    NaN
# 5                      NaN                  NaN                    NaN
# 6                      NaN                  NaN                    NaN
# 7                      NaN                  NaN                    NaN
# 8                      NaN                  NaN                    NaN
# 9                      NaN                  NaN                    NaN
#
#   contractPeriod_startDate contractPeriod_endDate
# 0                      NaN                    NaN  \
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
# 5                      NaN                    NaN
# 6                      NaN                    NaN
# 7                      NaN                    NaN
# 8                      NaN                    NaN
# 9                      NaN                    NaN
#
#    contractPeriod_maxExtentDate  contractPeriod_durationInDays
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
# 5                           NaN                            NaN
# 6                           NaN                            NaN
# 7                           NaN                            NaN
# 8                           NaN                            NaN
# 9                           NaN                            NaN

# %%
#Columnas 
awards_2023_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status', 'date',
#        'amount', 'currency', 'correctedValue_amount',
#        'correctedValue_currency', 'enteredValue_amount',
#        'enteredValue_currency', 'contractPeriod_startDate',
#        'contractPeriod_endDate', 'contractPeriod_maxExtentDate',
#        'contractPeriod_durationInDays'],
#       dtype='object')

# %%
awards_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104910 entries, 0 to 104909
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           104910 non-null  object
#  1   release_id                     104910 non-null  object
#  2   id                             104910 non-null  object
#  3   title                          0 non-null       float64
#  4   description                    18997 non-null   object
#  5   status                         82203 non-null   object
#  6   date                           15763 non-null   object
#  7   amount                         104908 non-null  float64
#  8   currency                       104908 non-null  object
#  9   correctedValue_amount          0 non-null       float64
#  10  correctedValue_currency        0 non-null       float64
#  11  enteredValue_amount            0 non-null       float64
#  12  enteredValue_currency          0 non-null       float64
#  13  contractPeriod_startDate       3365 non-null    object
#  14  contractPeriod_endDate         3365 non-null    object
#  15  contractPeriod_maxExtentDate   0 non-null       float64
#  16  contractPeriod_durationInDays  3364 non-null    float64
# dtypes: float64(8), object(9)
# memory usage: 13.6+ MB

# %% [markdown]
# ### contracts_2023.csv

# %%
contracts_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[1]),sep=",")
contracts_2023_df.head(10)
# Out:
#                                   ocid
# 0  ocds-5wno2w-CE-20230002374213-30375  \
# 1  ocds-5wno2w-CE-20230002374214-30375
# 2  ocds-5wno2w-CE-20230002374215-30375
# 3  ocds-5wno2w-CE-20230002374216-30375
# 4  ocds-5wno2w-CE-20230002374217-30375
# 5  ocds-5wno2w-CE-20230002374218-30375
# 6  ocds-5wno2w-CE-20230002374219-30375
# 7  ocds-5wno2w-CE-20230002374220-30375
# 8  ocds-5wno2w-CE-20230002374221-30375
# 9  ocds-5wno2w-CE-20230002374222-30375
#
#                                          release_id
# 0  CE-20230002374213-30375-2023-08-31T01:28:26.479Z  \
# 1  CE-20230002374214-30375-2023-08-31T01:28:26.493Z
# 2  CE-20230002374215-30375-2023-08-31T01:28:26.507Z
# 3  CE-20230002374216-30375-2023-08-31T01:28:26.520Z
# 4  CE-20230002374217-30375-2023-08-31T01:28:26.537Z
# 5  CE-20230002374218-30375-2023-08-31T01:28:26.553Z
# 6  CE-20230002374219-30375-2023-08-31T01:28:26.573Z
# 7  CE-20230002374220-30375-2023-08-31T01:28:26.592Z
# 8  CE-20230002374221-30375-2023-08-31T01:28:26.613Z
# 9  CE-20230002374222-30375-2023-08-31T01:28:26.632Z
#
#                            id            awardID  title  description
# 0  CE-20230002374213-contract  CE-20230002374213    NaN          NaN  \
# 1  CE-20230002374214-contract  CE-20230002374214    NaN          NaN
# 2  CE-20230002374215-contract  CE-20230002374215    NaN          NaN
# 3  CE-20230002374216-contract  CE-20230002374216    NaN          NaN
# 4  CE-20230002374217-contract  CE-20230002374217    NaN          NaN
# 5  CE-20230002374218-contract  CE-20230002374218    NaN          NaN
# 6  CE-20230002374219-contract  CE-20230002374219    NaN          NaN
# 7  CE-20230002374220-contract  CE-20230002374220    NaN          NaN
# 8  CE-20230002374221-contract  CE-20230002374221    NaN          NaN
# 9  CE-20230002374222-contract  CE-20230002374222    NaN          NaN
#
#        status contractPeriod_startDate contractPeriod_endDate
# 0  terminated                      NaN                    NaN  \
# 1  terminated                      NaN                    NaN
# 2  terminated                      NaN                    NaN
# 3  terminated                      NaN                    NaN
# 4  terminated                      NaN                    NaN
# 5  terminated                      NaN                    NaN
# 6  terminated                      NaN                    NaN
# 7  terminated                      NaN                    NaN
# 8  terminated                      NaN                    NaN
# 9  terminated                      NaN                    NaN
#
#    contractPeriod_maxExtentDate  contractPeriod_durationInDays  amount
# 0                           NaN                            NaN     NaN  \
# 1                           NaN                            NaN     NaN
# 2                           NaN                            NaN     NaN
# 3                           NaN                            NaN     NaN
# 4                           NaN                            NaN     NaN
# 5                           NaN                            NaN     NaN
# 6                           NaN                            NaN     NaN
# 7                           NaN                            NaN     NaN
# 8                           NaN                            NaN     NaN
# 9                           NaN                            NaN     NaN
#
#   currency dateSigned
# 0      NaN        NaN
# 1      NaN        NaN
# 2      NaN        NaN
# 3      NaN        NaN
# 4      NaN        NaN
# 5      NaN        NaN
# 6      NaN        NaN
# 7      NaN        NaN
# 8      NaN        NaN
# 9      NaN        NaN

# %%
#Columnas
contracts_2023_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98684 entries, 0 to 98683
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ocid                           98684 non-null  object
#  1   release_id                     98684 non-null  object
#  2   id                             98684 non-null  object
#  3   awardID                        98684 non-null  object
#  4   title                          0 non-null      float64
#  5   description                    0 non-null      float64
#  6   status                         98684 non-null  object
#  7   contractPeriod_startDate       12772 non-null  object
#  8   contractPeriod_endDate         12772 non-null  object
#  9   contractPeriod_maxExtentDate   0 non-null      float64
#  10  contractPeriod_durationInDays  12768 non-null  float64
#  11  amount                         12772 non-null  float64
#  12  currency                       12772 non-null  object
#  13  dateSigned                     12772 non-null  object
# dtypes: float64(5), object(9)
# memory usage: 10.5+ MB

# %% [markdown]
# ### extensions_2023.csv

# %%
extensions_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[2]),sep=",")
extensions_2023_df.head(10)
# Out:
#                                            extension
# 0  https://raw.githubusercontent.com/open-contrac...
# 1  https://raw.githubusercontent.com/open-contrac...
# 2  https://raw.githubusercontent.com/open-contrac...
# 3  https://raw.githubusercontent.com/GobiernoFaci...
# 4  https://gitlab.com/dncp-opendata/ocds_auctions...
# 5  https://raw.githubusercontent.com/open-contrac...
# 6  https://raw.githubusercontent.com/open-contrac...

# %%
#Columnas
contracts_2023_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98684 entries, 0 to 98683
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ocid                           98684 non-null  object
#  1   release_id                     98684 non-null  object
#  2   id                             98684 non-null  object
#  3   awardID                        98684 non-null  object
#  4   title                          0 non-null      float64
#  5   description                    0 non-null      float64
#  6   status                         98684 non-null  object
#  7   contractPeriod_startDate       12772 non-null  object
#  8   contractPeriod_endDate         12772 non-null  object
#  9   contractPeriod_maxExtentDate   0 non-null      float64
#  10  contractPeriod_durationInDays  12768 non-null  float64
#  11  amount                         12772 non-null  float64
#  12  currency                       12772 non-null  object
#  13  dateSigned                     12772 non-null  object
# dtypes: float64(5), object(9)
# memory usage: 10.5+ MB

# %% [markdown]
# ### metadata_2023.csv

# %%
metadata_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[3]),sep=",")
metadata_2023_df.head(10)
# Out:
#                                                  Uri  Version
# 0  https://portal.compraspublicas.gob.ec/sercop/d...      1.1  \
#
#                                        PublisherName PublisherScheme
# 0  Servicio Nacional de Contratación Pública (SER...            OCDS  \
#
#   PublisherUid                        PublisherUri
# 0  ocds-5wno2w  https://www.compraspublicas.gob.ec  \
#
#                                            License
# 0  https://creativecommons.org/licenses/by/3.0/ec/  \
#
#                                    PublicationPolicy             PublishedDate
# 0  https://datosabiertos.compraspublicas.gob.ec/P...  2023-09-01T21:15:38.820Z

# %%
#Columnas
metadata_2023_df.columns
# Out:
# Index(['Uri', 'Version', 'PublisherName', 'PublisherScheme', 'PublisherUid',
#        'PublisherUri', 'License', 'PublicationPolicy', 'PublishedDate'],
#       dtype='object')

# %% [markdown]
# ### planning_2023.csv

# %%
planning_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[4]),sep=",")
planning_2023_df.head(10)
# Out:
#                                       ocid
# 0   ocds-5wno2w-SIE-CELHNA-102-2023-238940  \
# 1  ocds-5wno2w-CCD-EPMT-SD-004-2023-479584
# 2    ocds-5wno2w-CD-001-GADMJC-2023-128892
# 3   ocds-5wno2w-CD-004-GADPRPN-2023-287439
# 4    ocds-5wno2w-CD01-PDOT-2023-SJB-126213
# 5   ocds-5wno2w-CDC-002-GADPRG-2023-110713
# 6   ocds-5wno2w-CDC-003-GADP5J-2023-283536
# 7  ocds-5wno2w-CDC-18D06-001-2023-R-543076
# 8    ocds-5wno2w-CDC-ACTEP-001-2023-702285
# 9     ocds-5wno2w-CDC-AGP-002A-2023-462963
#
#                                                   id
# 0  SIE-CELHNA-102-2023-238940-2023-08-31T04:09:20...  \
# 1  CCD-EPMT-SD-004-2023-479584-2023-08-31T04:12:3...
# 2  CD-001-GADMJC-2023-128892-2023-08-31T04:05:46....
# 3  CD-004-GADPRPN-2023-287439-2023-08-31T04:05:40...
# 4  CD01-PDOT-2023-SJB-126213-2023-08-31T04:06:03....
# 5  CDC-002-GADPRG-2023-110713-2023-08-31T04:05:51...
# 6  CDC-003-GADP5J-2023-283536-2023-08-31T04:06:02...
# 7  CDC-18D06-001-2023-R-543076-2023-08-31T04:00:1...
# 8  CDC-ACTEP-001-2023-702285-2023-08-31T04:11:42....
# 9  CDC-AGP-002A-2023-462963-2023-08-31T04:05:26.5...
#
#                                            rationale
# 0  HNA ADQUISICION DE UN TORNO PARA EL TALLER MEC...  \
# 1  SERVICIO DE AUDITORIA EXTERNA, PARA DICTAMINAR...
# 2  CONTRATACIÓN DE LOS SERVICIOS DE ACTUALIZACIÓN...
# 3  TÉRMINOS DE REFERENCIA PARA LA CONTRATACIÓN DE...
# 4  “ACTUALIZACIÓN DEL PLAN DE DESARROLLO Y ORDENA...
# 5  FISCALIZACIÓN DE LA CONSTRUCCION DE DOS CANCHA...
# 6  CONTRATACION DE SERVICIOS DE CONSULTORIA ACTUA...
# 7  CONTRATACION DE FISCALIZACION PARA EL PROCESO ...
# 8  CONSULTORIA PARA LA ELABORACION Y/O REFORMA DE...
# 9  CONTRATACIÓN DEL SERVICIO DE AUDITORÍA PARA LA...
#
#                                            budget_id  budget_description
# 0                                                NaN                 NaN  \
# 1                                          110530602                 NaN
# 2                                            7306010                 NaN
# 3                                             730605                 NaN
# 4                                             730601                 NaN
# 5                                           73.06.04                 NaN
# 6                                             730601                 NaN
# 7  2023.140.6660.0000.60.00.008.006.000.1806.7306...                 NaN
# 8                                             530601                 NaN
# 9                                     700.000.530602                 NaN
#
#    budget_amount budget_currency
# 0            NaN             NaN
# 1        5000.00             USD
# 2       21600.53             USD
# 3       26000.00             USD
# 4       21875.00             USD
# 5        5500.00             USD
# 6       16000.00             USD
# 7       14574.63             USD
# 8       31760.00             USD
# 9       14000.00             USD

# %%
#Columnas
planning_2023_df.columns
# Out:
# Index(['ocid', 'id', 'rationale', 'budget_id', 'budget_description',
#        'budget_amount', 'budget_currency'],
#       dtype='object')

# %%
planning_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22208 entries, 0 to 22207
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ocid                22208 non-null  object
#  1   id                  22208 non-null  object
#  2   rationale           22208 non-null  object
#  3   budget_id           13634 non-null  object
#  4   budget_description  0 non-null      float64
#  5   budget_amount       9803 non-null   float64
#  6   budget_currency     9803 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 1.2+ MB

# %% [markdown]
# ### releases_2023.csv

# %%
releases_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[5]),sep=",")
releases_2023_df.head(10)
# Out:
#                                   ocid
# 0  ocds-5wno2w-CE-20230002374213-30375  \
# 1  ocds-5wno2w-CE-20230002374214-30375
# 2  ocds-5wno2w-CE-20230002374215-30375
# 3  ocds-5wno2w-CE-20230002374216-30375
# 4  ocds-5wno2w-CE-20230002374217-30375
# 5  ocds-5wno2w-CE-20230002374218-30375
# 6  ocds-5wno2w-CE-20230002374219-30375
# 7  ocds-5wno2w-CE-20230002374220-30375
# 8  ocds-5wno2w-CE-20230002374221-30375
# 9  ocds-5wno2w-CE-20230002374222-30375
#
#                                                  id initiationType
# 0  CE-20230002374213-30375-2023-08-31T01:28:26.479Z         tender  \
# 1  CE-20230002374214-30375-2023-08-31T01:28:26.493Z         tender
# 2  CE-20230002374215-30375-2023-08-31T01:28:26.507Z         tender
# 3  CE-20230002374216-30375-2023-08-31T01:28:26.520Z         tender
# 4  CE-20230002374217-30375-2023-08-31T01:28:26.537Z         tender
# 5  CE-20230002374218-30375-2023-08-31T01:28:26.553Z         tender
# 6  CE-20230002374219-30375-2023-08-31T01:28:26.573Z         tender
# 7  CE-20230002374220-30375-2023-08-31T01:28:26.592Z         tender
# 8  CE-20230002374221-30375-2023-08-31T01:28:26.613Z         tender
# 9  CE-20230002374222-30375-2023-08-31T01:28:26.632Z         tender
#
#                buyer_id                                         buyer_name
# 0  EC-RUC-0968580510001  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...  \
# 1  EC-RUC-0968580510001  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...
# 2  EC-RUC-0968580510001  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...
# 3  EC-RUC-0968580510001  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...
# 4  EC-RUC-0968580510001  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...
# 5  EC-RUC-0968580510001  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...
# 6  EC-RUC-0968580510001  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...
# 7  EC-RUC-0968580510001  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...
# 8  EC-RUC-0968580510001  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...
# 9  EC-RUC-0968580510001  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...
#
#   language                       date                            tag
# 0       es  2023-03-29T00:00:00-05:00  ["tender","award","contract"]
# 1       es  2023-03-29T00:00:00-05:00  ["tender","award","contract"]
# 2       es  2023-03-29T00:00:00-05:00  ["tender","award","contract"]
# 3       es  2023-03-29T00:00:00-05:00  ["tender","award","contract"]
# 4       es  2023-03-29T00:00:00-05:00  ["tender","award","contract"]
# 5       es  2023-03-29T00:00:00-05:00  ["tender","award","contract"]
# 6       es  2023-03-29T00:00:00-05:00  ["tender","award","contract"]
# 7       es  2023-03-29T00:00:00-05:00  ["tender","award","contract"]
# 8       es  2023-03-29T00:00:00-05:00  ["tender","award","contract"]
# 9       es  2023-03-29T00:00:00-05:00  ["tender","award","contract"]

# %%
#Columnas
releases_2023_df.columns
# Out:
# Index(['ocid', 'id', 'initiationType', 'buyer_id', 'buyer_name', 'language',
#        'date', 'tag'],
#       dtype='object')

# %%
releases_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108120 entries, 0 to 108119
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ocid            108120 non-null  object
#  1   id              108120 non-null  object
#  2   initiationType  108120 non-null  object
#  3   buyer_id        108120 non-null  object
#  4   buyer_name      108120 non-null  object
#  5   language        108120 non-null  object
#  6   date            108120 non-null  object
#  7   tag             108120 non-null  object
# dtypes: object(8)
# memory usage: 6.6+ MB

# %% [markdown]
# ### suppliers_2023.csv

# %%
suppliers_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[6]),sep=",")
suppliers_2023_df.head(10)
# Out:
#                                   ocid
# 0  ocds-5wno2w-CE-20230002374213-30375  \
# 1  ocds-5wno2w-CE-20230002374214-30375
# 2  ocds-5wno2w-CE-20230002374215-30375
# 3  ocds-5wno2w-CE-20230002374216-30375
# 4  ocds-5wno2w-CE-20230002374217-30375
# 5  ocds-5wno2w-CE-20230002374218-30375
# 6  ocds-5wno2w-CE-20230002374219-30375
# 7  ocds-5wno2w-CE-20230002374220-30375
# 8  ocds-5wno2w-CE-20230002374221-30375
# 9  ocds-5wno2w-CE-20230002374222-30375
#
#                                          release_id           award_id
# 0  CE-20230002374213-30375-2023-08-31T01:28:26.479Z  CE-20230002374213  \
# 1  CE-20230002374214-30375-2023-08-31T01:28:26.493Z  CE-20230002374214
# 2  CE-20230002374215-30375-2023-08-31T01:28:26.507Z  CE-20230002374215
# 3  CE-20230002374216-30375-2023-08-31T01:28:26.520Z  CE-20230002374216
# 4  CE-20230002374217-30375-2023-08-31T01:28:26.537Z  CE-20230002374217
# 5  CE-20230002374218-30375-2023-08-31T01:28:26.553Z  CE-20230002374218
# 6  CE-20230002374219-30375-2023-08-31T01:28:26.573Z  CE-20230002374219
# 7  CE-20230002374220-30375-2023-08-31T01:28:26.592Z  CE-20230002374220
# 8  CE-20230002374221-30375-2023-08-31T01:28:26.613Z  CE-20230002374221
# 9  CE-20230002374222-30375-2023-08-31T01:28:26.632Z  CE-20230002374222
#
#                           id                                          name
# 0  EC-RUC-1790732657001-2854  COMPAÑIA GENERAL DE COMERCIO COGECOMSA S. A.
# 1  EC-RUC-1790732657001-2854  COMPAÑIA GENERAL DE COMERCIO COGECOMSA S. A.
# 2  EC-RUC-1790732657001-2854  COMPAÑIA GENERAL DE COMERCIO COGECOMSA S. A.
# 3  EC-RUC-1790732657001-2854  COMPAÑIA GENERAL DE COMERCIO COGECOMSA S. A.
# 4  EC-RUC-1790732657001-2854  COMPAÑIA GENERAL DE COMERCIO COGECOMSA S. A.
# 5  EC-RUC-1790732657001-2854  COMPAÑIA GENERAL DE COMERCIO COGECOMSA S. A.
# 6  EC-RUC-1790732657001-2854  COMPAÑIA GENERAL DE COMERCIO COGECOMSA S. A.
# 7  EC-RUC-1790732657001-2854  COMPAÑIA GENERAL DE COMERCIO COGECOMSA S. A.
# 8  EC-RUC-1790732657001-2854  COMPAÑIA GENERAL DE COMERCIO COGECOMSA S. A.
# 9  EC-RUC-1790732657001-2854  COMPAÑIA GENERAL DE COMERCIO COGECOMSA S. A.

# %%
#Columnas
suppliers_2023_df.columns
# Out:
# Index(['ocid', 'release_id', 'award_id', 'id', 'name'], dtype='object')

# %%
suppliers_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104910 entries, 0 to 104909
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ocid        104910 non-null  object
#  1   release_id  104910 non-null  object
#  2   award_id    104910 non-null  object
#  3   id          104910 non-null  object
#  4   name        104901 non-null  object
# dtypes: object(5)
# memory usage: 4.0+ MB

# %% [markdown]
# ### tender_2023.csv

# %%
tender_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[7]),sep=",")
tender_2023_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_15726/133071985.py:1: DtypeWarning: Columns (12,13,14,15,16,18,19,20,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   tender_2023_df = pd.read_csv(os.path.join(datas_dir,datasa_2023[7]),sep=",")
#                                   ocid
# 0  ocds-5wno2w-CE-20230002374213-30375  \
# 1  ocds-5wno2w-CE-20230002374214-30375
# 2  ocds-5wno2w-CE-20230002374215-30375
# 3  ocds-5wno2w-CE-20230002374216-30375
# 4  ocds-5wno2w-CE-20230002374217-30375
# 5  ocds-5wno2w-CE-20230002374218-30375
# 6  ocds-5wno2w-CE-20230002374219-30375
# 7  ocds-5wno2w-CE-20230002374220-30375
# 8  ocds-5wno2w-CE-20230002374221-30375
# 9  ocds-5wno2w-CE-20230002374222-30375
#
#                                          release_id                       id
# 0  CE-20230002374213-30375-2023-08-31T01:28:26.479Z  CE-20230002374213-30375  \
# 1  CE-20230002374214-30375-2023-08-31T01:28:26.493Z  CE-20230002374214-30375
# 2  CE-20230002374215-30375-2023-08-31T01:28:26.507Z  CE-20230002374215-30375
# 3  CE-20230002374216-30375-2023-08-31T01:28:26.520Z  CE-20230002374216-30375
# 4  CE-20230002374217-30375-2023-08-31T01:28:26.537Z  CE-20230002374217-30375
# 5  CE-20230002374218-30375-2023-08-31T01:28:26.553Z  CE-20230002374218-30375
# 6  CE-20230002374219-30375-2023-08-31T01:28:26.573Z  CE-20230002374219-30375
# 7  CE-20230002374220-30375-2023-08-31T01:28:26.592Z  CE-20230002374220-30375
# 8  CE-20230002374221-30375-2023-08-31T01:28:26.613Z  CE-20230002374221-30375
# 9  CE-20230002374222-30375-2023-08-31T01:28:26.632Z  CE-20230002374222-30375
#
#                                title
# 0  Orden de compra CE-20230002374213  \
# 1  Orden de compra CE-20230002374214
# 2  Orden de compra CE-20230002374215
# 3  Orden de compra CE-20230002374216
# 4  Orden de compra CE-20230002374217
# 5  Orden de compra CE-20230002374218
# 6  Orden de compra CE-20230002374219
# 7  Orden de compra CE-20230002374220
# 8  Orden de compra CE-20230002374221
# 9  Orden de compra CE-20230002374222
#
#                                          description    status
# 0  Orden de compra para adquirir los siguientes p...  complete  \
# 1  Orden de compra para adquirir los siguientes p...  complete
# 2  Orden de compra para adquirir los siguientes p...  complete
# 3  Orden de compra para adquirir los siguientes p...  complete
# 4  Orden de compra para adquirir los siguientes p...  complete
# 5  Orden de compra para adquirir los siguientes p...  complete
# 6  Orden de compra para adquirir los siguientes p...  complete
# 7  Orden de compra para adquirir los siguientes p...  complete
# 8  Orden de compra para adquirir los siguientes p...  complete
# 9  Orden de compra para adquirir los siguientes p...  complete
#
#            procuringEntity_id
# 0  EC-RUC-0968580510001-30375  \
# 1  EC-RUC-0968580510001-30375
# 2  EC-RUC-0968580510001-30375
# 3  EC-RUC-0968580510001-30375
# 4  EC-RUC-0968580510001-30375
# 5  EC-RUC-0968580510001-30375
# 6  EC-RUC-0968580510001-30375
# 7  EC-RUC-0968580510001-30375
# 8  EC-RUC-0968580510001-30375
# 9  EC-RUC-0968580510001-30375
#
#                                 procuringEntity_name  value_amount
# 0  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...         63.59  \
# 1  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...        326.14
# 2  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...        114.11
# 3  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...         27.55
# 4  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...         73.85
# 5  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...         30.17
# 6  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...         30.17
# 7  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...         26.75
# 8  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...         32.86
# 9  GOBIERNO AUTONOMO DESCENTRALIZADO PROVINCIAL D...         68.54
#
#   value_currency procurementMethod
# 0            USD         selective  \
# 1            USD         selective
# 2            USD         selective
# 3            USD         selective
# 4            USD         selective
# 5            USD         selective
# 6            USD         selective
# 7            USD         selective
# 8            USD         selective
# 9            USD         selective
#
#                             procurementMethodDetails mainProcurementCategory
# 0  Catálogo electrónico - Mejor oferta en el conv...                     NaN  \
# 1  Catálogo electrónico - Mejor oferta en el conv...                     NaN
# 2  Catálogo electrónico - Mejor oferta en el conv...                     NaN
# 3  Catálogo electrónico - Mejor oferta en el conv...                     NaN
# 4  Catálogo electrónico - Mejor oferta en el conv...                     NaN
# 5  Catálogo electrónico - Mejor oferta en el conv...                     NaN
# 6  Catálogo electrónico - Mejor oferta en el conv...                     NaN
# 7  Catálogo electrónico - Mejor oferta en el conv...                     NaN
# 8  Catálogo electrónico - Mejor oferta en el conv...                     NaN
# 9  Catálogo electrónico - Mejor oferta en el conv...                     NaN
#
#   awardCriteria tenderPeriod_startDate tenderPeriod_endDate
# 0           NaN                    NaN                  NaN  \
# 1           NaN                    NaN                  NaN
# 2           NaN                    NaN                  NaN
# 3           NaN                    NaN                  NaN
# 4           NaN                    NaN                  NaN
# 5           NaN                    NaN                  NaN
# 6           NaN                    NaN                  NaN
# 7           NaN                    NaN                  NaN
# 8           NaN                    NaN                  NaN
# 9           NaN                    NaN                  NaN
#
#   tenderPeriod_maxExtentDate  tenderPeriod_durationInDays
# 0                        NaN                          NaN  \
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
# 5                        NaN                          NaN
# 6                        NaN                          NaN
# 7                        NaN                          NaN
# 8                        NaN                          NaN
# 9                        NaN                          NaN
#
#   enquiryPeriod_startDate enquiryPeriod_endDate enquiryPeriod_maxExtentDate
# 0                     NaN                   NaN                         NaN  \
# 1                     NaN                   NaN                         NaN
# 2                     NaN                   NaN                         NaN
# 3                     NaN                   NaN                         NaN
# 4                     NaN                   NaN                         NaN
# 5                     NaN                   NaN                         NaN
# 6                     NaN                   NaN                         NaN
# 7                     NaN                   NaN                         NaN
# 8                     NaN                   NaN                         NaN
# 9                     NaN                   NaN                         NaN
#
#    enquiryPeriod_durationInDays hasEnquiries eligibilityCriteria
# 0                           NaN          NaN                 NaN  \
# 1                           NaN          NaN                 NaN
# 2                           NaN          NaN                 NaN
# 3                           NaN          NaN                 NaN
# 4                           NaN          NaN                 NaN
# 5                           NaN          NaN                 NaN
# 6                           NaN          NaN                 NaN
# 7                           NaN          NaN                 NaN
# 8                           NaN          NaN                 NaN
# 9                           NaN          NaN                 NaN
#
#   awardPeriod_startDate awardPeriod_endDate awardPeriod_maxExtentDate
# 0                   NaN                 NaN                       NaN  \
# 1                   NaN                 NaN                       NaN
# 2                   NaN                 NaN                       NaN
# 3                   NaN                 NaN                       NaN
# 4                   NaN                 NaN                       NaN
# 5                   NaN                 NaN                       NaN
# 6                   NaN                 NaN                       NaN
# 7                   NaN                 NaN                       NaN
# 8                   NaN                 NaN                       NaN
# 9                   NaN                 NaN                       NaN
#
#    awardPeriod_durationInDays  numberOfTenderers
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                         NaN                NaN
# 3                         NaN                NaN
# 4                         NaN                NaN
# 5                         NaN                NaN
# 6                         NaN                NaN
# 7                         NaN                NaN
# 8                         NaN                NaN
# 9                         NaN                NaN

# %%
#Columnas
tender_2023_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status',
#        'procuringEntity_id', 'procuringEntity_name', 'value_amount',
#        'value_currency', 'procurementMethod', 'procurementMethodDetails',
#        'mainProcurementCategory', 'awardCriteria', 'tenderPeriod_startDate',
#        'tenderPeriod_endDate', 'tenderPeriod_maxExtentDate',
#        'tenderPeriod_durationInDays', 'enquiryPeriod_startDate',
#        'enquiryPeriod_endDate', 'enquiryPeriod_maxExtentDate',
#        'enquiryPeriod_durationInDays', 'hasEnquiries', 'eligibilityCriteria',
#        'awardPeriod_startDate', 'awardPeriod_endDate',
#        'awardPeriod_maxExtentDate', 'awardPeriod_durationInDays',
#        'numberOfTenderers'],
#       dtype='object')

# %%
tender_2023_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105268 entries, 0 to 105267
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ocid                          105268 non-null  object
#  1   release_id                    105268 non-null  object
#  2   id                            105268 non-null  object
#  3   title                         105268 non-null  object
#  4   description                   105268 non-null  object
#  5   status                        105268 non-null  object
#  6   procuringEntity_id            105268 non-null  object
#  7   procuringEntity_name          105268 non-null  object
#  8   value_amount                  94479 non-null   float64
#  9   value_currency                94479 non-null   object
#  10  procurementMethod             105268 non-null  object
#  11  procurementMethodDetails      105268 non-null  object
#  12  mainProcurementCategory       19356 non-null   object
#  13  awardCriteria                 19356 non-null   object
#  14  tenderPeriod_startDate        19356 non-null   object
#  15  tenderPeriod_endDate          7152 non-null    object
#  16  tenderPeriod_maxExtentDate    7152 non-null    object
#  17  tenderPeriod_durationInDays   6962 non-null    float64
#  18  enquiryPeriod_startDate       19356 non-null   object
#  19  enquiryPeriod_endDate         16436 non-null   object
#  20  enquiryPeriod_maxExtentDate   16436 non-null   object
#  21  enquiryPeriod_durationInDays  15962 non-null   float64
#  22  hasEnquiries                  12657 non-null   object
#  23  eligibilityCriteria           8567 non-null    object
#  24  awardPeriod_startDate         10789 non-null   object
#  25  awardPeriod_endDate           19356 non-null   object
#  26  awardPeriod_maxExtentDate     19356 non-null   object
#  27  awardPeriod_durationInDays    10446 non-null   float64
#  28  numberOfTenderers             19311 non-null   float64
# dtypes: float64(5), object(24)
# memory usage: 23.3+ MB
