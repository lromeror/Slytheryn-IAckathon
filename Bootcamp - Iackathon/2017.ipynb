# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2017

# %%
datasa_2017=["awards_2017.csv","contracts_2017.csv","extensions_2017.csv","metadata_2017.csv","planning_2017.csv","releases_2017.csv","suppliers_2017.csv","tender_2017.csv"]
datas_dir ="assets/data/releases_2017/"
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### awards_2017.csv

# %%
awards_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[0]),sep=",")
awards_2017_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_66788/1631092483.py:1: DtypeWarning: Columns (4,5,6,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   awards_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[0]),sep=",")
#                                      ocid
# 0  ocds-5wno2w-RE-CSBSUCUA-2017-002-82297  \
# 1   ocds-5wno2w-MCO-006-GADMCB-2017-91641
# 2  ocds-5wno2w-RE-CSBSUCUA-2017-003-82297
# 3        ocds-5wno2w-RE-UC-009-2017-30951
# 4   ocds-5wno2w-RE-UOCAIP-004-2017-431940
# 5   ocds-5wno2w-SIE-BANEC-014-2017-722820
# 6    ocds-5wno2w-SIE-FAME-091-2017-510646
# 7   ocds-5wno2w-SIE-HJCA-B-173-2017-87497
# 8     ocds-5wno2w-SIE-HVCM-035-2017-12070
# 9     ocds-5wno2w-SIE-HVCM-036-2017-12070
#
#                                           release_id
# 0  RE-CSBSUCUA-2017-002-82297-2021-12-02T00:01:31...  \
# 1  MCO-006-GADMCB-2017-91641-2021-12-01T21:59:09....
# 2  RE-CSBSUCUA-2017-003-82297-2021-12-02T00:01:34...
# ...

# %%
#Columnas 
awards_2017_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status', 'date',
#        'amount', 'currency', 'correctedValue_amount',
#        'correctedValue_currency', 'enteredValue_amount',
#        'enteredValue_currency', 'contractPeriod_startDate',
#        'contractPeriod_endDate', 'contractPeriod_maxExtentDate',
#        'contractPeriod_durationInDays'],
#       dtype='object')

# %%
awards_2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337608 entries, 0 to 337607
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           337608 non-null  object
#  1   release_id                     337608 non-null  object
#  2   id                             337608 non-null  object
#  3   title                          0 non-null       float64
#  4   description                    46839 non-null   object
#  5   status                         290747 non-null  object
#  6   date                           37278 non-null   object
#  7   amount                         337601 non-null  float64
#  8   currency                       337602 non-null  object
#  9   correctedValue_amount          0 non-null       float64
#  10  correctedValue_currency        0 non-null       float64
#  11  enteredValue_amount            0 non-null       float64
# ...

# %% [markdown]
# ### contracts_2017.csv

# %%
contracts_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[1]),sep=",")
contracts_2017_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_66788/310470185.py:1: DtypeWarning: Columns (7,8,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   contracts_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[1]),sep=",")
#                                      ocid
# 0  ocds-5wno2w-RE-CSBSUCUA-2017-002-82297  \
# 1  ocds-5wno2w-RE-CSBSUCUA-2017-003-82297
# 2        ocds-5wno2w-RE-UC-009-2017-30951
# 3   ocds-5wno2w-SIE-BANEC-014-2017-722820
# 4    ocds-5wno2w-SIE-FAME-091-2017-510646
# 5   ocds-5wno2w-SIE-HJCA-B-173-2017-87497
# 6     ocds-5wno2w-SIE-HVCM-035-2017-12070
# 7     ocds-5wno2w-SIE-HVCM-036-2017-12070
# 8      ocds-5wno2w-SIE-UC-001-2017.-30951
# 9       ocds-5wno2w-CDC-BDE-010-2017-2435
#
#                                           release_id
# 0  RE-CSBSUCUA-2017-002-82297-2021-12-02T00:01:31...  \
# 1  RE-CSBSUCUA-2017-003-82297-2021-12-02T00:01:34...
# 2      RE-UC-009-2017-30951-2021-12-01T22:07:00.822Z
# ...

# %%
#Columnas
contracts_2017_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328347 entries, 0 to 328346
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           328347 non-null  object
#  1   release_id                     328347 non-null  object
#  2   id                             328347 non-null  object
#  3   awardID                        328347 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         328347 non-null  object
#  7   contractPeriod_startDate       37595 non-null   object
#  8   contractPeriod_endDate         37595 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  37548 non-null   float64
#  11  amount                         37595 non-null   float64
# ...

# %% [markdown]
# ### extensions_2017.csv

# %%
extensions_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[2]),sep=",")
extensions_2017_df.head(10)
# Out:
#                                            extension
# 0  https://raw.githubusercontent.com/open-contrac...
# 1  https://raw.githubusercontent.com/open-contrac...
# 2  https://raw.githubusercontent.com/open-contrac...
# 3  https://raw.githubusercontent.com/GobiernoFaci...
# 4  https://gitlab.com/dncp-opendata/ocds_auctions...
# 5  https://raw.githubusercontent.com/open-contrac...
# 6  https://raw.githubusercontent.com/open-contrac...

# %%
#Columnas
contracts_2017_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328347 entries, 0 to 328346
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           328347 non-null  object
#  1   release_id                     328347 non-null  object
#  2   id                             328347 non-null  object
#  3   awardID                        328347 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         328347 non-null  object
#  7   contractPeriod_startDate       37595 non-null   object
#  8   contractPeriod_endDate         37595 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  37548 non-null   float64
#  11  amount                         37595 non-null   float64
# ...

# %% [markdown]
# ### metadata_2017.csv

# %%
metadata_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[3]),sep=",")
metadata_2017_df.head(10)
# Out:
#                                                  Uri  Version
# 0  https://portal.compraspublicas.gob.ec/sercop/d...      1.1  \
#
#                                        PublisherName PublisherScheme
# 0  Servicio Nacional de Contratación Pública (SER...            OCDS  \
#
#   PublisherUid                        PublisherUri
# 0  ocds-5wno2w  https://www.compraspublicas.gob.ec  \
#
#                                            License
# 0  https://creativecommons.org/licenses/by/3.0/ec/  \
#
#                                    PublicationPolicy             PublishedDate
# 0  https://datosabiertos.compraspublicas.gob.ec/P...  2021-12-03T05:39:29.183Z

# %%
#Columnas
metadata_2017_df.columns
# Out:
# Index(['Uri', 'Version', 'PublisherName', 'PublisherScheme', 'PublisherUid',
#        'PublisherUri', 'License', 'PublicationPolicy', 'PublishedDate'],
#       dtype='object')

# %% [markdown]
# ### planning_2017.csv

# %%
planning_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[4]),sep=",")
planning_2017_df.head(10)
# Out:
#                                      ocid
# 0  ocds-5wno2w-RE-CSBSUCUA-2017-002-82297  \
# 1   ocds-5wno2w-MCO-006-GADMCB-2017-91641
# 2  ocds-5wno2w-RE-CSBSUCUA-2017-003-82297
# 3        ocds-5wno2w-RE-UC-009-2017-30951
# 4   ocds-5wno2w-RE-UOCAIP-004-2017-431940
# 5   ocds-5wno2w-SIE-BANEC-014-2017-722820
# 6    ocds-5wno2w-SIE-FAME-091-2017-510646
# 7   ocds-5wno2w-SIE-HJCA-B-173-2017-87497
# 8     ocds-5wno2w-SIE-HVCM-035-2017-12070
# 9     ocds-5wno2w-SIE-HVCM-036-2017-12070
#
#                                                   id
# 0  RE-CSBSUCUA-2017-002-82297-2021-12-02T00:01:31...  \
# 1  MCO-006-GADMCB-2017-91641-2021-12-01T21:59:09....
# 2  RE-CSBSUCUA-2017-003-82297-2021-12-02T00:01:34...
# 3      RE-UC-009-2017-30951-2021-12-01T22:07:00.822Z
# 4  RE-UOCAIP-004-2017-431940-2021-12-02T02:58:55....
# 5  SIE-BANEC-014-2017-722820-2021-12-01T22:14:14....
# 6  SIE-FAME-091-2017-510646-2021-12-01T23:12:00.413Z
# 7  SIE-HJCA-B-173-2017-87497-2021-12-01T22:32:57....
# ...

# %%
#Columnas
planning_2017_df.columns
# Out:
# Index(['ocid', 'id', 'rationale', 'budget_id', 'budget_description',
#        'budget_amount', 'budget_currency'],
#       dtype='object')

# %%
planning_2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43528 entries, 0 to 43527
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ocid                43528 non-null  object
#  1   id                  43528 non-null  object
#  2   rationale           43528 non-null  object
#  3   budget_id           43528 non-null  object
#  4   budget_description  0 non-null      float64
#  5   budget_amount       25002 non-null  float64
#  6   budget_currency     25002 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# ### releases_2017.csv

# %%
releases_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[5]),sep=",")
releases_2017_df.head(10)
# Out:
#                                      ocid
# 0  ocds-5wno2w-RE-CSBSUCUA-2017-002-82297  \
# 1   ocds-5wno2w-MCO-006-GADMCB-2017-91641
# 2  ocds-5wno2w-RE-CSBSUCUA-2017-003-82297
# 3        ocds-5wno2w-RE-UC-009-2017-30951
# 4   ocds-5wno2w-RE-UOCAIP-004-2017-431940
# 5   ocds-5wno2w-SIE-BANEC-014-2017-722820
# 6    ocds-5wno2w-SIE-FAME-091-2017-510646
# 7   ocds-5wno2w-SIE-HJCA-B-173-2017-87497
# 8     ocds-5wno2w-SIE-HVCM-035-2017-12070
# 9     ocds-5wno2w-SIE-HVCM-036-2017-12070
#
#                                                   id initiationType
# 0  RE-CSBSUCUA-2017-002-82297-2021-12-02T00:01:31...         tender  \
# 1  MCO-006-GADMCB-2017-91641-2021-12-01T21:59:09....         tender
# 2  RE-CSBSUCUA-2017-003-82297-2021-12-02T00:01:34...         tender
# 3      RE-UC-009-2017-30951-2021-12-01T22:07:00.822Z         tender
# 4  RE-UOCAIP-004-2017-431940-2021-12-02T02:58:55....         tender
# 5  SIE-BANEC-014-2017-722820-2021-12-01T22:14:14....         tender
# ...

# %%
#Columnas
releases_2017_df.columns
# Out:
# Index(['ocid', 'id', 'initiationType', 'buyer_id', 'buyer_name', 'language',
#        'date', 'tag'],
#       dtype='object')

# %%
releases_2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334275 entries, 0 to 334274
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ocid            334275 non-null  object
#  1   id              334275 non-null  object
#  2   initiationType  334275 non-null  object
#  3   buyer_id        334275 non-null  object
#  4   buyer_name      334275 non-null  object
#  5   language        334275 non-null  object
#  6   date            334275 non-null  object
#  7   tag             334275 non-null  object
# dtypes: object(8)
# memory usage: 20.4+ MB

# %% [markdown]
# ### suppliers_2017.csv

# %%
suppliers_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[6]),sep=",")
suppliers_2017_df.head(10)
# Out:
#                                      ocid
# 0  ocds-5wno2w-RE-CSBSUCUA-2017-002-82297  \
# 1   ocds-5wno2w-MCO-006-GADMCB-2017-91641
# 2  ocds-5wno2w-RE-CSBSUCUA-2017-003-82297
# 3        ocds-5wno2w-RE-UC-009-2017-30951
# 4   ocds-5wno2w-RE-UOCAIP-004-2017-431940
# 5   ocds-5wno2w-SIE-BANEC-014-2017-722820
# 6    ocds-5wno2w-SIE-FAME-091-2017-510646
# 7   ocds-5wno2w-SIE-HJCA-B-173-2017-87497
# 8     ocds-5wno2w-SIE-HVCM-035-2017-12070
# 9     ocds-5wno2w-SIE-HVCM-036-2017-12070
#
#                                           release_id
# 0  RE-CSBSUCUA-2017-002-82297-2021-12-02T00:01:31...  \
# 1  MCO-006-GADMCB-2017-91641-2021-12-01T21:59:09....
# 2  RE-CSBSUCUA-2017-003-82297-2021-12-02T00:01:34...
# 3      RE-UC-009-2017-30951-2021-12-01T22:07:00.822Z
# 4  RE-UOCAIP-004-2017-431940-2021-12-02T02:58:55....
# 5  SIE-BANEC-014-2017-722820-2021-12-01T22:14:14....
# 6  SIE-FAME-091-2017-510646-2021-12-01T23:12:00.413Z
# 7  SIE-HJCA-B-173-2017-87497-2021-12-01T22:32:57....
# ...

# %%
#Columnas
suppliers_2017_df.columns
# Out:
# Index(['ocid', 'release_id', 'award_id', 'id', 'name'], dtype='object')

# %%
suppliers_2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337602 entries, 0 to 337601
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ocid        337602 non-null  object
#  1   release_id  337602 non-null  object
#  2   award_id    337602 non-null  object
#  3   id          337602 non-null  object
#  4   name        337601 non-null  object
# dtypes: object(5)
# memory usage: 12.9+ MB

# %% [markdown]
# ### tender_2017.csv

# %%
tender_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[7]),sep=",")
tender_2017_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_66788/3072696484.py:1: DtypeWarning: Columns (12,13,14,15,16,18,19,20,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   tender_2017_df = pd.read_csv(os.path.join(datas_dir,datasa_2017[7]),sep=",")
#                                      ocid
# 0  ocds-5wno2w-RE-CSBSUCUA-2017-002-82297  \
# 1   ocds-5wno2w-MCO-006-GADMCB-2017-91641
# 2  ocds-5wno2w-RE-CSBSUCUA-2017-003-82297
# 3        ocds-5wno2w-RE-UC-009-2017-30951
# 4   ocds-5wno2w-RE-UOCAIP-004-2017-431940
# 5   ocds-5wno2w-SIE-BANEC-014-2017-722820
# 6    ocds-5wno2w-SIE-FAME-091-2017-510646
# 7   ocds-5wno2w-SIE-HJCA-B-173-2017-87497
# 8     ocds-5wno2w-SIE-HVCM-035-2017-12070
# 9     ocds-5wno2w-SIE-HVCM-036-2017-12070
#
#                                           release_id
# 0  RE-CSBSUCUA-2017-002-82297-2021-12-02T00:01:31...  \
# 1  MCO-006-GADMCB-2017-91641-2021-12-01T21:59:09....
# ...

# %%
#Columnas
tender_2017_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status',
#        'procuringEntity_id', 'procuringEntity_name', 'value_amount',
#        'value_currency', 'procurementMethod', 'procurementMethodDetails',
#        'mainProcurementCategory', 'awardCriteria', 'tenderPeriod_startDate',
#        'tenderPeriod_endDate', 'tenderPeriod_maxExtentDate',
#        'tenderPeriod_durationInDays', 'enquiryPeriod_startDate',
#        'enquiryPeriod_endDate', 'enquiryPeriod_maxExtentDate',
#        'enquiryPeriod_durationInDays', 'hasEnquiries', 'eligibilityCriteria',
#        'awardPeriod_startDate', 'awardPeriod_endDate',
#        'awardPeriod_maxExtentDate', 'awardPeriod_durationInDays',
#        'numberOfTenderers'],
#       dtype='object')

# %%
tender_2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334274 entries, 0 to 334273
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ocid                          334274 non-null  object
#  1   release_id                    334274 non-null  object
#  2   id                            334274 non-null  object
#  3   title                         334274 non-null  object
#  4   description                   334274 non-null  object
#  5   status                        334274 non-null  object
#  6   procuringEntity_id            334274 non-null  object
#  7   procuringEntity_name          334274 non-null  object
#  8   value_amount                  315747 non-null  float64
#  9   value_currency                315748 non-null  object
#  10  procurementMethod             334274 non-null  object
#  11  procurementMethodDetails      334274 non-null  object
# ...
