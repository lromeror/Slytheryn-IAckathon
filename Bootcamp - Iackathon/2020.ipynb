# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2020

# %%
datasa_2020=["awards_2020.csv","contracts_2020.csv","extensions_2020.csv","metadata_2020.csv","planning_2020.csv","releases_2020.csv","suppliers_2020.csv","tender_2020.csv"]
datas_dir ="assets/data/releases_2020/"
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### awards_2020.csv

# %%
awards_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[0]),sep=",")
awards_2020_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_68034/1910740268.py:1: DtypeWarning: Columns (4,6,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   awards_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[0]),sep=",")
#                                    ocid
# 0  ocds-5wno2w-CE-20200001803954-116350  \
# 1  ocds-5wno2w-CE-20200001803956-116350
# 2  ocds-5wno2w-CE-20200001803957-116350
# 3  ocds-5wno2w-CE-20200001803958-116350
# 4  ocds-5wno2w-CE-20200001803959-116350
# 5  ocds-5wno2w-CE-20200001803960-116350
# 6  ocds-5wno2w-CE-20200001803961-116350
# 7  ocds-5wno2w-CE-20200001803962-116350
# 8  ocds-5wno2w-CE-20200001803963-116350
# 9  ocds-5wno2w-CE-20200001803964-116350
#
#                                           release_id                 id
# 0  CE-20200001803954-116350-2021-11-26T16:56:50.058Z  CE-20200001803954  \
# 1  CE-20200001803956-116350-2021-11-26T16:56:50.109Z  CE-20200001803956
# ...

# %%
#Columnas 
awards_2020_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status', 'date',
#        'amount', 'currency', 'correctedValue_amount',
#        'correctedValue_currency', 'enteredValue_amount',
#        'enteredValue_currency', 'contractPeriod_startDate',
#        'contractPeriod_endDate', 'contractPeriod_maxExtentDate',
#        'contractPeriod_durationInDays'],
#       dtype='object')

# %%
awards_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161881 entries, 0 to 161880
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           161881 non-null  object
#  1   release_id                     161881 non-null  object
#  2   id                             161881 non-null  object
#  3   title                          0 non-null       float64
#  4   description                    29220 non-null   object
#  5   status                         132574 non-null  object
#  6   date                           24245 non-null   object
#  7   amount                         161881 non-null  float64
#  8   currency                       161881 non-null  object
#  9   correctedValue_amount          0 non-null       float64
#  10  correctedValue_currency        0 non-null       float64
#  11  enteredValue_amount            0 non-null       float64
# ...

# %% [markdown]
# ### contracts_2020.csv

# %%
contracts_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[1]),sep=",")
contracts_2020_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_68034/2899858356.py:1: DtypeWarning: Columns (7,8,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   contracts_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[1]),sep=",")
#                                    ocid
# 0  ocds-5wno2w-CE-20200001803954-116350  \
# 1  ocds-5wno2w-CE-20200001803956-116350
# 2  ocds-5wno2w-CE-20200001803957-116350
# 3  ocds-5wno2w-CE-20200001803958-116350
# 4  ocds-5wno2w-CE-20200001803959-116350
# 5  ocds-5wno2w-CE-20200001803960-116350
# 6  ocds-5wno2w-CE-20200001803961-116350
# 7  ocds-5wno2w-CE-20200001803962-116350
# 8  ocds-5wno2w-CE-20200001803963-116350
# 9  ocds-5wno2w-CE-20200001803964-116350
#
#                                           release_id
# 0  CE-20200001803954-116350-2021-11-26T16:56:50.058Z  \
# 1  CE-20200001803956-116350-2021-11-26T16:56:50.109Z
# 2  CE-20200001803957-116350-2021-11-26T16:56:50.155Z
# ...

# %%
#Columnas
contracts_2020_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155192 entries, 0 to 155191
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           155192 non-null  object
#  1   release_id                     155192 non-null  object
#  2   id                             155192 non-null  object
#  3   awardID                        155192 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         155192 non-null  object
#  7   contractPeriod_startDate       22530 non-null   object
#  8   contractPeriod_endDate         22530 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  22517 non-null   float64
#  11  amount                         22530 non-null   float64
# ...

# %% [markdown]
# ### extensions_2020.csv

# %%
extensions_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[2]),sep=",")
extensions_2020_df.head(10)
# Out:
#                                            extension
# 0  https://raw.githubusercontent.com/open-contrac...
# 1  https://raw.githubusercontent.com/open-contrac...
# 2  https://raw.githubusercontent.com/open-contrac...
# 3  https://raw.githubusercontent.com/GobiernoFaci...
# 4  https://gitlab.com/dncp-opendata/ocds_auctions...
# 5  https://raw.githubusercontent.com/open-contrac...
# 6  https://raw.githubusercontent.com/open-contrac...

# %%
#Columnas
contracts_2020_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155192 entries, 0 to 155191
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           155192 non-null  object
#  1   release_id                     155192 non-null  object
#  2   id                             155192 non-null  object
#  3   awardID                        155192 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         155192 non-null  object
#  7   contractPeriod_startDate       22530 non-null   object
#  8   contractPeriod_endDate         22530 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  22517 non-null   float64
#  11  amount                         22530 non-null   float64
# ...

# %% [markdown]
# ### metadata_2020.csv

# %%
metadata_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[3]),sep=",")
metadata_2020_df.head(10)
# Out:
#                                                  Uri  Version
# 0  https://portal.compraspublicas.gob.ec/sercop/d...      1.1  \
#
#                                        PublisherName PublisherScheme
# 0  Servicio Nacional de Contratación Pública (SER...            OCDS  \
#
#   PublisherUid                        PublisherUri
# 0  ocds-5wno2w  https://www.compraspublicas.gob.ec  \
#
#                                            License
# 0  https://creativecommons.org/licenses/by/3.0/ec/  \
#
#                                    PublicationPolicy             PublishedDate
# 0  https://datosabiertos.compraspublicas.gob.ec/P...  2022-01-01T16:22:33.299Z

# %%
#Columnas
metadata_2020_df.columns
# Out:
# Index(['Uri', 'Version', 'PublisherName', 'PublisherScheme', 'PublisherUid',
#        'PublisherUri', 'License', 'PublicationPolicy', 'PublishedDate'],
#       dtype='object')

# %% [markdown]
# ### planning_2020.csv

# %%
planning_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[4]),sep=",")
planning_2020_df.head(10)
# Out:
#                                      ocid
# 0     ocds-5wno2w-SIE-023-HMHP-2020-11080  \
# 1     ocds-5wno2w-SIE-HVCM-044-2020-12070
# 2     ocds-5wno2w-SIE-ISSFA-2020-048-2803
# 3     ocds-5wno2w-SIE-ISSFA-2020-050-2803
# 4    ocds-5wno2w-RE-HGSVP-14-CO-2020-2724
# 5    ocds-5wno2w-LICO-MIMG-016-2020-44856
# 6     ocds-5wno2w-SIE-ISSFA-2020-053-2803
# 7  ocds-5wno2w-SIE-EECS-DF-131-2020-56835
# 8     ocds-5wno2w-SIE-ISSFA-2020-054-2803
# 9     ocds-5wno2w-SIE-ISSFA-2020-055-2803
#
#                                                   id
# 0   SIE-023-HMHP-2020-11080-2021-11-29T14:28:18.950Z  \
# 1   SIE-HVCM-044-2020-12070-2021-11-30T23:52:26.598Z
# 2   SIE-ISSFA-2020-048-2803-2021-11-30T23:41:17.649Z
# 3   SIE-ISSFA-2020-050-2803-2021-11-30T23:42:29.544Z
# 4  RE-HGSVP-14-CO-2020-2724-2021-11-29T14:35:23.229Z
# 5  LICO-MIMG-016-2020-44856-2021-12-01T00:52:51.708Z
# 6   SIE-ISSFA-2020-053-2803-2021-11-30T23:42:20.756Z
# 7  SIE-EECS-DF-131-2020-56835-2021-12-01T00:34:17...
# ...

# %%
#Columnas
planning_2020_df.columns
# Out:
# Index(['ocid', 'id', 'rationale', 'budget_id', 'budget_description',
#        'budget_amount', 'budget_currency'],
#       dtype='object')

# %%
planning_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28017 entries, 0 to 28016
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ocid                28017 non-null  object
#  1   id                  28017 non-null  object
#  2   rationale           28016 non-null  object
#  3   budget_id           28017 non-null  object
#  4   budget_description  0 non-null      float64
#  5   budget_amount       14202 non-null  float64
#  6   budget_currency     14202 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# ### releases_2020.csv

# %%
releases_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[5]),sep=",")
releases_2020_df.head(10)
# Out:
#                                    ocid
# 0  ocds-5wno2w-CE-20200001803954-116350  \
# 1  ocds-5wno2w-CE-20200001803956-116350
# 2  ocds-5wno2w-CE-20200001803957-116350
# 3  ocds-5wno2w-CE-20200001803958-116350
# 4  ocds-5wno2w-CE-20200001803959-116350
# 5  ocds-5wno2w-CE-20200001803960-116350
# 6  ocds-5wno2w-CE-20200001803961-116350
# 7  ocds-5wno2w-CE-20200001803962-116350
# 8  ocds-5wno2w-CE-20200001803963-116350
# 9  ocds-5wno2w-CE-20200001803964-116350
#
#                                                   id initiationType
# 0  CE-20200001803954-116350-2021-11-26T16:56:50.058Z         tender  \
# 1  CE-20200001803956-116350-2021-11-26T16:56:50.109Z         tender
# 2  CE-20200001803957-116350-2021-11-26T16:56:50.155Z         tender
# 3  CE-20200001803958-116350-2021-11-26T16:56:50.200Z         tender
# 4  CE-20200001803959-116350-2021-11-26T16:56:50.239Z         tender
# 5  CE-20200001803960-116350-2021-11-26T16:56:50.277Z         tender
# ...

# %%
#Columnas
releases_2020_df.columns
# Out:
# Index(['ocid', 'id', 'initiationType', 'buyer_id', 'buyer_name', 'language',
#        'date', 'tag'],
#       dtype='object')

# %%
releases_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160676 entries, 0 to 160675
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ocid            160676 non-null  object
#  1   id              160676 non-null  object
#  2   initiationType  160676 non-null  object
#  3   buyer_id        160676 non-null  object
#  4   buyer_name      160676 non-null  object
#  5   language        160676 non-null  object
#  6   date            160676 non-null  object
#  7   tag             160676 non-null  object
# dtypes: object(8)
# memory usage: 9.8+ MB

# %% [markdown]
# ### suppliers_2020.csv

# %%
suppliers_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[6]),sep=",")
suppliers_2020_df.head(10)
# Out:
#                                    ocid
# 0  ocds-5wno2w-CE-20200001803954-116350  \
# 1  ocds-5wno2w-CE-20200001803956-116350
# 2  ocds-5wno2w-CE-20200001803957-116350
# 3  ocds-5wno2w-CE-20200001803958-116350
# 4  ocds-5wno2w-CE-20200001803959-116350
# 5  ocds-5wno2w-CE-20200001803960-116350
# 6  ocds-5wno2w-CE-20200001803961-116350
# 7  ocds-5wno2w-CE-20200001803962-116350
# 8  ocds-5wno2w-CE-20200001803963-116350
# 9  ocds-5wno2w-CE-20200001803964-116350
#
#                                           release_id           award_id
# 0  CE-20200001803954-116350-2021-11-26T16:56:50.058Z  CE-20200001803954  \
# 1  CE-20200001803956-116350-2021-11-26T16:56:50.109Z  CE-20200001803956
# 2  CE-20200001803957-116350-2021-11-26T16:56:50.155Z  CE-20200001803957
# 3  CE-20200001803958-116350-2021-11-26T16:56:50.200Z  CE-20200001803958
# 4  CE-20200001803959-116350-2021-11-26T16:56:50.239Z  CE-20200001803959
# 5  CE-20200001803960-116350-2021-11-26T16:56:50.277Z  CE-20200001803960
# ...

# %%
#Columnas
suppliers_2020_df.columns
# Out:
# Index(['ocid', 'release_id', 'award_id', 'id', 'name'], dtype='object')

# %%
suppliers_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161881 entries, 0 to 161880
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ocid        161881 non-null  object
#  1   release_id  161881 non-null  object
#  2   award_id    161881 non-null  object
#  3   id          161881 non-null  object
#  4   name        161868 non-null  object
# dtypes: object(5)
# memory usage: 6.2+ MB

# %% [markdown]
# ### tender_2020.csv

# %%
tender_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[7]),sep=",")
tender_2020_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_68034/2630361409.py:1: DtypeWarning: Columns (12,13,14,15,16,18,19,20,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   tender_2020_df = pd.read_csv(os.path.join(datas_dir,datasa_2020[7]),sep=",")
#                                    ocid
# 0  ocds-5wno2w-CE-20200001803954-116350  \
# 1  ocds-5wno2w-CE-20200001803956-116350
# 2  ocds-5wno2w-CE-20200001803957-116350
# 3  ocds-5wno2w-CE-20200001803958-116350
# 4  ocds-5wno2w-CE-20200001803959-116350
# 5  ocds-5wno2w-CE-20200001803960-116350
# 6  ocds-5wno2w-CE-20200001803961-116350
# 7  ocds-5wno2w-CE-20200001803962-116350
# 8  ocds-5wno2w-CE-20200001803963-116350
# 9  ocds-5wno2w-CE-20200001803964-116350
#
#                                           release_id
# 0  CE-20200001803954-116350-2021-11-26T16:56:50.058Z  \
# 1  CE-20200001803956-116350-2021-11-26T16:56:50.109Z
# 2  CE-20200001803957-116350-2021-11-26T16:56:50.155Z
# ...

# %%
#Columnas
tender_2020_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status',
#        'procuringEntity_id', 'procuringEntity_name', 'value_amount',
#        'value_currency', 'procurementMethod', 'procurementMethodDetails',
#        'mainProcurementCategory', 'awardCriteria', 'tenderPeriod_startDate',
#        'tenderPeriod_endDate', 'tenderPeriod_maxExtentDate',
#        'tenderPeriod_durationInDays', 'enquiryPeriod_startDate',
#        'enquiryPeriod_endDate', 'enquiryPeriod_maxExtentDate',
#        'enquiryPeriod_durationInDays', 'hasEnquiries', 'eligibilityCriteria',
#        'awardPeriod_startDate', 'awardPeriod_endDate',
#        'awardPeriod_maxExtentDate', 'awardPeriod_durationInDays',
#        'numberOfTenderers'],
#       dtype='object')

# %%
tender_2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160676 entries, 0 to 160675
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ocid                          160676 non-null  object
#  1   release_id                    160676 non-null  object
#  2   id                            160676 non-null  object
#  3   title                         160676 non-null  object
#  4   description                   160675 non-null  object
#  5   status                        160676 non-null  object
#  6   procuringEntity_id            160676 non-null  object
#  7   procuringEntity_name          160676 non-null  object
#  8   value_amount                  146861 non-null  float64
#  9   value_currency                146861 non-null  object
#  10  procurementMethod             160676 non-null  object
#  11  procurementMethodDetails      160676 non-null  object
# ...
