# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2016

# %%
datasa_2016=["awards_2016.csv","contracts_2016.csv","extensions_2016.csv","metadata_2016.csv","planning_2016.csv","releases_2016.csv","suppliers_2016.csv","tender_2016.csv"]
datas_dir ="assets/data/releases_2016/"
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### awards_2016.csv

# %%
awards_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[0]),sep=",")
awards_2016_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_66126/1842288664.py:1: DtypeWarning: Columns (4,5,6,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   awards_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[0]),sep=",")
#                                      ocid
# 0     ocds-5wno2w-CDC-CPEC-008A-2016-3264  \
# 1   ocds-5wno2w-CDC-CPMCP-002-2016-592427
# 2  ocds-5wno2w-CDC-EPMAPS-005-2016-258814
# 3     ocds-5wno2w-CDC-EEASA-070-2016-3233
# 4      ocds-5wno2w-CDC-CBDMQ-03-2016-2525
# 5    ocds-5wno2w-CDC-CELHPA-011-16-240714
# 6     ocds-5wno2w-CDC-GAD-I-006-2016-2783
# 7       ocds-5wno2w-003-CC-PIDR-2016-2583
# 8       ocds-5wno2w-001-CC-PIDR-2016-2583
# 9   ocds-5wno2w-001-CLC-RPCFO-2016-374548
#
#                                           release_id
# 0   CDC-CPEC-008A-2016-3264-2021-12-02T11:40:24.884Z  \
# 1  CDC-CPMCP-002-2016-592427-2021-12-02T08:20:03....
# 2  CDC-EPMAPS-005-2016-258814-2021-12-02T09:26:14...
# ...

# %%
#Columnas 
awards_2016_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status', 'date',
#        'amount', 'currency', 'correctedValue_amount',
#        'correctedValue_currency', 'enteredValue_amount',
#        'enteredValue_currency', 'contractPeriod_startDate',
#        'contractPeriod_endDate', 'contractPeriod_maxExtentDate',
#        'contractPeriod_durationInDays'],
#       dtype='object')

# %%
awards_2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283987 entries, 0 to 283986
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           283987 non-null  object
#  1   release_id                     283987 non-null  object
#  2   id                             283987 non-null  object
#  3   title                          0 non-null       float64
#  4   description                    47628 non-null   object
#  5   status                         236326 non-null  object
#  6   date                           38652 non-null   object
#  7   amount                         283977 non-null  float64
#  8   currency                       283987 non-null  object
#  9   correctedValue_amount          0 non-null       float64
#  10  correctedValue_currency        0 non-null       float64
#  11  enteredValue_amount            0 non-null       float64
# ...

# %% [markdown]
# ### contracts_2016.csv

# %%
contracts_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[1]),sep=",")
contracts_2016_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_66126/3601167713.py:1: DtypeWarning: Columns (7,8,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   contracts_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[1]),sep=",")
#                                      ocid
# 0     ocds-5wno2w-CDC-CPEC-008A-2016-3264  \
# 1   ocds-5wno2w-CDC-CPMCP-002-2016-592427
# 2  ocds-5wno2w-CDC-EPMAPS-005-2016-258814
# 3     ocds-5wno2w-CDC-EEASA-070-2016-3233
# 4      ocds-5wno2w-CDC-CBDMQ-03-2016-2525
# 5    ocds-5wno2w-CDC-CELHPA-011-16-240714
# 6     ocds-5wno2w-CDC-GAD-I-006-2016-2783
# 7       ocds-5wno2w-001-CC-PIDR-2016-2583
# 8   ocds-5wno2w-001-CLC-RPCFO-2016-374548
# 9    ocds-5wno2w-001-DPEC-CNE-2016-121514
#
#                                           release_id
# 0   CDC-CPEC-008A-2016-3264-2021-12-02T11:40:24.884Z  \
# 1  CDC-CPMCP-002-2016-592427-2021-12-02T08:20:03....
# 2  CDC-EPMAPS-005-2016-258814-2021-12-02T09:26:14...
# ...

# %%
#Columnas
contracts_2016_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274495 entries, 0 to 274494
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           274495 non-null  object
#  1   release_id                     274495 non-null  object
#  2   id                             274495 non-null  object
#  3   awardID                        274495 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         274495 non-null  object
#  7   contractPeriod_startDate       38146 non-null   object
#  8   contractPeriod_endDate         38146 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  38086 non-null   float64
#  11  amount                         38146 non-null   float64
# ...

# %% [markdown]
# ### extensions_2016.csv

# %%
extensions_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[2]),sep=",")
extensions_2016_df.head(10)
# Out:
#                                            extension
# 0  https://raw.githubusercontent.com/open-contrac...
# 1  https://raw.githubusercontent.com/open-contrac...
# 2  https://raw.githubusercontent.com/open-contrac...
# 3  https://raw.githubusercontent.com/GobiernoFaci...
# 4  https://gitlab.com/dncp-opendata/ocds_auctions...
# 5  https://raw.githubusercontent.com/open-contrac...
# 6  https://raw.githubusercontent.com/open-contrac...

# %%
#Columnas
contracts_2016_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274495 entries, 0 to 274494
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           274495 non-null  object
#  1   release_id                     274495 non-null  object
#  2   id                             274495 non-null  object
#  3   awardID                        274495 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         274495 non-null  object
#  7   contractPeriod_startDate       38146 non-null   object
#  8   contractPeriod_endDate         38146 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  38086 non-null   float64
#  11  amount                         38146 non-null   float64
# ...

# %% [markdown]
# ### metadata_2016.csv

# %%
metadata_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[3]),sep=",")
metadata_2016_df.head(10)
# Out:
#                                                  Uri  Version
# 0  https://portal.compraspublicas.gob.ec/sercop/d...      1.1  \
#
#                                        PublisherName PublisherScheme
# 0  Servicio Nacional de Contratación Pública (SER...            OCDS  \
#
#   PublisherUid                        PublisherUri
# 0  ocds-5wno2w  https://www.compraspublicas.gob.ec  \
#
#                                            License
# 0  https://creativecommons.org/licenses/by/3.0/ec/  \
#
#                                    PublicationPolicy             PublishedDate
# 0  https://datosabiertos.compraspublicas.gob.ec/P...  2021-12-03T05:39:29.183Z

# %%
#Columnas
metadata_2016_df.columns
# Out:
# Index(['Uri', 'Version', 'PublisherName', 'PublisherScheme', 'PublisherUid',
#        'PublisherUri', 'License', 'PublicationPolicy', 'PublishedDate'],
#       dtype='object')

# %% [markdown]
# ### planning_2016.csv

# %%
planning_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[4]),sep=",")
planning_2016_df.head(10)
# Out:
#                                      ocid
# 0     ocds-5wno2w-CDC-CPEC-008A-2016-3264  \
# 1   ocds-5wno2w-CDC-CPMCP-002-2016-592427
# 2  ocds-5wno2w-CDC-EPMAPS-005-2016-258814
# 3     ocds-5wno2w-CDC-EEASA-070-2016-3233
# 4      ocds-5wno2w-CDC-CBDMQ-03-2016-2525
# 5    ocds-5wno2w-CDC-CELHPA-011-16-240714
# 6     ocds-5wno2w-CDC-GAD-I-006-2016-2783
# 7       ocds-5wno2w-003-CC-PIDR-2016-2583
# 8       ocds-5wno2w-001-CC-PIDR-2016-2583
# 9   ocds-5wno2w-001-CLC-RPCFO-2016-374548
#
#                                                   id
# 0   CDC-CPEC-008A-2016-3264-2021-12-02T11:40:24.884Z  \
# 1  CDC-CPMCP-002-2016-592427-2021-12-02T08:20:03....
# 2  CDC-EPMAPS-005-2016-258814-2021-12-02T09:26:14...
# 3   CDC-EEASA-070-2016-3233-2021-12-02T09:16:33.592Z
# 4    CDC-CBDMQ-03-2016-2525-2021-12-02T08:19:43.973Z
# 5  CDC-CELHPA-011-16-240714-2021-12-02T07:30:56.795Z
# 6   CDC-GAD-I-006-2016-2783-2021-12-02T08:23:51.192Z
# 7     003-CC-PIDR-2016-2583-2021-12-02T12:48:52.590Z
# ...

# %%
#Columnas
planning_2016_df.columns
# Out:
# Index(['ocid', 'id', 'rationale', 'budget_id', 'budget_description',
#        'budget_amount', 'budget_currency'],
#       dtype='object')

# %%
planning_2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43310 entries, 0 to 43309
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ocid                43310 non-null  object
#  1   id                  43310 non-null  object
#  2   rationale           43310 non-null  object
#  3   budget_id           43310 non-null  object
#  4   budget_description  0 non-null      float64
#  5   budget_amount       22998 non-null  float64
#  6   budget_currency     22998 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# ### releases_2023.csv

# %%
releases_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[5]),sep=",")
releases_2016_df.head(10)
# Out:
#                                      ocid
# 0     ocds-5wno2w-CDC-CPEC-008A-2016-3264  \
# 1   ocds-5wno2w-CDC-CPMCP-002-2016-592427
# 2  ocds-5wno2w-CDC-EPMAPS-005-2016-258814
# 3     ocds-5wno2w-CDC-EEASA-070-2016-3233
# 4      ocds-5wno2w-CDC-CBDMQ-03-2016-2525
# 5    ocds-5wno2w-CDC-CELHPA-011-16-240714
# 6     ocds-5wno2w-CDC-GAD-I-006-2016-2783
# 7       ocds-5wno2w-003-CC-PIDR-2016-2583
# 8       ocds-5wno2w-001-CC-PIDR-2016-2583
# 9   ocds-5wno2w-001-CLC-RPCFO-2016-374548
#
#                                                   id initiationType
# 0   CDC-CPEC-008A-2016-3264-2021-12-02T11:40:24.884Z         tender  \
# 1  CDC-CPMCP-002-2016-592427-2021-12-02T08:20:03....         tender
# 2  CDC-EPMAPS-005-2016-258814-2021-12-02T09:26:14...         tender
# 3   CDC-EEASA-070-2016-3233-2021-12-02T09:16:33.592Z         tender
# 4    CDC-CBDMQ-03-2016-2525-2021-12-02T08:19:43.973Z         tender
# 5  CDC-CELHPA-011-16-240714-2021-12-02T07:30:56.795Z         tender
# ...

# %%
#Columnas
releases_2016_df.columns
# Out:
# Index(['ocid', 'id', 'initiationType', 'buyer_id', 'buyer_name', 'language',
#        'date', 'tag'],
#       dtype='object')

# %%
releases_2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279636 entries, 0 to 279635
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ocid            279636 non-null  object
#  1   id              279636 non-null  object
#  2   initiationType  279636 non-null  object
#  3   buyer_id        279636 non-null  object
#  4   buyer_name      279636 non-null  object
#  5   language        279636 non-null  object
#  6   date            279636 non-null  object
#  7   tag             279636 non-null  object
# dtypes: object(8)
# memory usage: 17.1+ MB

# %% [markdown]
# ### suppliers_2016.csv

# %%
suppliers_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[6]),sep=",")
suppliers_2016_df.head(10)
# Out:
#                                      ocid
# 0     ocds-5wno2w-CDC-CPEC-008A-2016-3264  \
# 1   ocds-5wno2w-CDC-CPMCP-002-2016-592427
# 2  ocds-5wno2w-CDC-EPMAPS-005-2016-258814
# 3     ocds-5wno2w-CDC-EEASA-070-2016-3233
# 4      ocds-5wno2w-CDC-CBDMQ-03-2016-2525
# 5    ocds-5wno2w-CDC-CELHPA-011-16-240714
# 6     ocds-5wno2w-CDC-GAD-I-006-2016-2783
# 7       ocds-5wno2w-003-CC-PIDR-2016-2583
# 8       ocds-5wno2w-001-CC-PIDR-2016-2583
# 9   ocds-5wno2w-001-CLC-RPCFO-2016-374548
#
#                                           release_id
# 0   CDC-CPEC-008A-2016-3264-2021-12-02T11:40:24.884Z  \
# 1  CDC-CPMCP-002-2016-592427-2021-12-02T08:20:03....
# 2  CDC-EPMAPS-005-2016-258814-2021-12-02T09:26:14...
# 3   CDC-EEASA-070-2016-3233-2021-12-02T09:16:33.592Z
# 4    CDC-CBDMQ-03-2016-2525-2021-12-02T08:19:43.973Z
# 5  CDC-CELHPA-011-16-240714-2021-12-02T07:30:56.795Z
# 6   CDC-GAD-I-006-2016-2783-2021-12-02T08:23:51.192Z
# 7     003-CC-PIDR-2016-2583-2021-12-02T12:48:52.590Z
# ...

# %%
#Columnas
suppliers_2016_df.columns
# Out:
# Index(['ocid', 'release_id', 'award_id', 'id', 'name'], dtype='object')

# %%
suppliers_2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283977 entries, 0 to 283976
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ocid        283977 non-null  object
#  1   release_id  283977 non-null  object
#  2   award_id    283977 non-null  object
#  3   id          283977 non-null  object
#  4   name        283975 non-null  object
# dtypes: object(5)
# memory usage: 10.8+ MB

# %% [markdown]
# ### tender_2016.csv

# %%
tender_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[7]),sep=",")
tender_2016_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_66126/3353831476.py:1: DtypeWarning: Columns (12,13,14,15,16,18,19,20,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   tender_2016_df = pd.read_csv(os.path.join(datas_dir,datasa_2016[7]),sep=",")
#                                      ocid
# 0     ocds-5wno2w-CDC-CPEC-008A-2016-3264  \
# 1   ocds-5wno2w-CDC-CPMCP-002-2016-592427
# 2  ocds-5wno2w-CDC-EPMAPS-005-2016-258814
# 3     ocds-5wno2w-CDC-EEASA-070-2016-3233
# 4      ocds-5wno2w-CDC-CBDMQ-03-2016-2525
# 5    ocds-5wno2w-CDC-CELHPA-011-16-240714
# 6     ocds-5wno2w-CDC-GAD-I-006-2016-2783
# 7       ocds-5wno2w-003-CC-PIDR-2016-2583
# 8       ocds-5wno2w-001-CC-PIDR-2016-2583
# 9   ocds-5wno2w-001-CLC-RPCFO-2016-374548
#
#                                           release_id
# 0   CDC-CPEC-008A-2016-3264-2021-12-02T11:40:24.884Z  \
# 1  CDC-CPMCP-002-2016-592427-2021-12-02T08:20:03....
# ...

# %%
#Columnas
tender_2016_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status',
#        'procuringEntity_id', 'procuringEntity_name', 'value_amount',
#        'value_currency', 'procurementMethod', 'procurementMethodDetails',
#        'mainProcurementCategory', 'awardCriteria', 'tenderPeriod_startDate',
#        'tenderPeriod_endDate', 'tenderPeriod_maxExtentDate',
#        'tenderPeriod_durationInDays', 'enquiryPeriod_startDate',
#        'enquiryPeriod_endDate', 'enquiryPeriod_maxExtentDate',
#        'enquiryPeriod_durationInDays', 'hasEnquiries', 'eligibilityCriteria',
#        'awardPeriod_startDate', 'awardPeriod_endDate',
#        'awardPeriod_maxExtentDate', 'awardPeriod_durationInDays',
#        'numberOfTenderers'],
#       dtype='object')

# %%
tender_2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279635 entries, 0 to 279634
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ocid                          279635 non-null  object
#  1   release_id                    279635 non-null  object
#  2   id                            279635 non-null  object
#  3   title                         279635 non-null  object
#  4   description                   279635 non-null  object
#  5   status                        279635 non-null  object
#  6   procuringEntity_id            279635 non-null  object
#  7   procuringEntity_name          279635 non-null  object
#  8   value_amount                  259313 non-null  float64
#  9   value_currency                259323 non-null  object
#  10  procurementMethod             279635 non-null  object
#  11  procurementMethodDetails      279635 non-null  object
# ...
