# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2021

# %%
datasa_2021=["awards_2021.csv","contracts_2021.csv","extensions_2021.csv","metadata_2021.csv","planning_2021.csv","releases_2021.csv","suppliers_2021.csv","tender_2021.csv"]
datas_dir ="assets/data/releases_2021/"
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### awards_2021.csv

# %%
awards_2021_df = pd.read_csv(os.path.join(datas_dir,datasa_2021[0]),sep=",")
awards_2021_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_68787/2773927864.py:1: DtypeWarning: Columns (4,6,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   awards_2021_df = pd.read_csv(os.path.join(datas_dir,datasa_2021[0]),sep=",")
#                                       ocid
# 0  ocds-5wno2w-SIE-EPMFCR-2021-001A-877354  \
# 1   ocds-5wno2w-SIE-EPP-2020849-21.-253178
# 2  ocds-5wno2w-SIE-EPP-2021000-1-21-253178
# 3    ocds-5wno2w-SIE-EPP-2021048-21-253178
# 4    ocds-5wno2w-SIE-EPP-2021064-21-253178
# 5    ocds-5wno2w-SIE-EPP-2021054-21-253178
# 6    ocds-5wno2w-SIE-GADMCU-2021-006-72903
# 7     ocds-5wno2w-SIE-NDSM-015-2021-185868
# 8    ocds-5wno2w-MCO-GADC-1643UE-1221-2616
# 9    ocds-5wno2w-MCO-GADC-1646UE-1221-2616
#
#                                           release_id
# 0  SIE-EPMFCR-2021-001A-877354-2022-02-24T10:16:4...  \
# 1  SIE-EPP-2020849-21.-253178-2022-10-13T18:32:47...
# 2  SIE-EPP-2021000-1-21-253178-2022-04-07T11:20:3...
# ...

# %%
#Columnas 
awards_2021_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status', 'date',
#        'amount', 'currency', 'correctedValue_amount',
#        'correctedValue_currency', 'enteredValue_amount',
#        'enteredValue_currency', 'contractPeriod_startDate',
#        'contractPeriod_endDate', 'contractPeriod_maxExtentDate',
#        'contractPeriod_durationInDays'],
#       dtype='object')

# %%
awards_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166983 entries, 0 to 166982
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           166983 non-null  object
#  1   release_id                     166983 non-null  object
#  2   id                             166983 non-null  object
#  3   title                          0 non-null       float64
#  4   description                    38129 non-null   object
#  5   status                         118407 non-null  object
#  6   date                           30470 non-null   object
#  7   amount                         166980 non-null  float64
#  8   currency                       166980 non-null  object
#  9   correctedValue_amount          0 non-null       float64
#  10  correctedValue_currency        0 non-null       float64
#  11  enteredValue_amount            0 non-null       float64
# ...

# %% [markdown]
# ### contracts_2021.csv

# %%
contracts_2021_df = pd.read_csv(os.path.join(datas_dir,datasa_2021[1]),sep=",")
contracts_2021_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-SIE-EPMFCR-2021-001A-877354  \
# 1   ocds-5wno2w-SIE-EPP-2020849-21.-253178
# 2  ocds-5wno2w-SIE-EPP-2021000-1-21-253178
# 3    ocds-5wno2w-SIE-EPP-2021048-21-253178
# 4    ocds-5wno2w-SIE-EPP-2021064-21-253178
# 5    ocds-5wno2w-SIE-EPP-2021054-21-253178
# 6    ocds-5wno2w-SIE-GADMCU-2021-006-72903
# 7     ocds-5wno2w-SIE-NDSM-015-2021-185868
# 8    ocds-5wno2w-MCO-GADC-1643UE-1221-2616
# 9    ocds-5wno2w-MCO-GADC-1646UE-1221-2616
#
#                                           release_id
# 0  SIE-EPMFCR-2021-001A-877354-2022-02-24T10:16:4...  \
# 1  SIE-EPP-2020849-21.-253178-2022-10-13T18:32:47...
# 2  SIE-EPP-2021000-1-21-253178-2022-04-07T11:20:3...
# 3  SIE-EPP-2021048-21-253178-2022-06-30T13:04:34....
# 4  SIE-EPP-2021064-21-253178-2022-03-19T11:20:40....
# 5  SIE-EPP-2021054-21-253178-2022-06-14T12:30:22....
# 6  SIE-GADMCU-2021-006-72903-2022-02-24T10:07:40....
# 7  SIE-NDSM-015-2021-185868-2022-02-24T10:08:40.9...
# ...

# %%
#Columnas
contracts_2021_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158199 entries, 0 to 158198
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           158199 non-null  object
#  1   release_id                     158199 non-null  object
#  2   id                             158199 non-null  object
#  3   awardID                        158199 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         158199 non-null  object
#  7   contractPeriod_startDate       29345 non-null   object
#  8   contractPeriod_endDate         29345 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  29341 non-null   float64
#  11  amount                         29345 non-null   float64
# ...

# %% [markdown]
# ### extensions_2021.csv

# %%
extensions_2021_df = pd.read_csv(os.path.join(datas_dir,datasa_2021[2]),sep=",")
extensions_2021_df.head(10)
# Out:
#                                            extension
# 0  https://raw.githubusercontent.com/open-contrac...
# 1  https://raw.githubusercontent.com/open-contrac...
# 2  https://raw.githubusercontent.com/open-contrac...
# 3  https://raw.githubusercontent.com/GobiernoFaci...
# 4  https://gitlab.com/dncp-opendata/ocds_auctions...
# 5  https://raw.githubusercontent.com/open-contrac...
# 6  https://raw.githubusercontent.com/open-contrac...

# %%
#Columnas
contracts_2021_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158199 entries, 0 to 158198
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           158199 non-null  object
#  1   release_id                     158199 non-null  object
#  2   id                             158199 non-null  object
#  3   awardID                        158199 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         158199 non-null  object
#  7   contractPeriod_startDate       29345 non-null   object
#  8   contractPeriod_endDate         29345 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  29341 non-null   float64
#  11  amount                         29345 non-null   float64
# ...

# %% [markdown]
# ### metadata_2021.csv

# %%
metadata_2021_df = pd.read_csv(os.path.join(datas_dir,datasa_2021[3]),sep=",")
metadata_2021_df.head(10)
# Out:
#                                                  Uri  Version
# 0  https://portal.compraspublicas.gob.ec/sercop/d...      1.1  \
#
#                                        PublisherName PublisherScheme
# 0  Servicio Nacional de Contratación Pública (SER...            OCDS  \
#
#   PublisherUid                        PublisherUri
# 0  ocds-5wno2w  https://www.compraspublicas.gob.ec  \
#
#                                            License
# 0  https://creativecommons.org/licenses/by/3.0/ec/  \
#
#                                    PublicationPolicy             PublishedDate
# 0  https://datosabiertos.compraspublicas.gob.ec/P...  2022-12-31T16:45:12.593Z

# %%
#Columnas
metadata_2021_df.columns
# Out:
# Index(['Uri', 'Version', 'PublisherName', 'PublisherScheme', 'PublisherUid',
#        'PublisherUri', 'License', 'PublicationPolicy', 'PublishedDate'],
#       dtype='object')

# %% [markdown]
# ### planning_2021.csv

# %%
planning_2021_df = pd.read_csv(os.path.join(datas_dir,datasa_2021[4]),sep=",")
planning_2021_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-SIE-EPMFCR-2021-001A-877354  \
# 1   ocds-5wno2w-SIE-EPP-2020849-21.-253178
# 2  ocds-5wno2w-SIE-EPP-2021000-1-21-253178
# 3    ocds-5wno2w-SIE-EPP-2021048-21-253178
# 4    ocds-5wno2w-SIE-EPP-2021064-21-253178
# 5    ocds-5wno2w-SIE-EPP-2021054-21-253178
# 6    ocds-5wno2w-SIE-GADMCU-2021-006-72903
# 7     ocds-5wno2w-SIE-NDSM-015-2021-185868
# 8    ocds-5wno2w-MCO-GADC-1643UE-1221-2616
# 9    ocds-5wno2w-MCO-GADC-1646UE-1221-2616
#
#                                                   id
# 0  SIE-EPMFCR-2021-001A-877354-2022-02-24T10:16:4...  \
# 1  SIE-EPP-2020849-21.-253178-2022-10-13T18:32:47...
# 2  SIE-EPP-2021000-1-21-253178-2022-04-07T11:20:3...
# 3  SIE-EPP-2021048-21-253178-2022-06-30T13:04:34....
# 4  SIE-EPP-2021064-21-253178-2022-03-19T11:20:40....
# 5  SIE-EPP-2021054-21-253178-2022-06-14T12:30:22....
# 6  SIE-GADMCU-2021-006-72903-2022-02-24T10:07:40....
# 7  SIE-NDSM-015-2021-185868-2022-02-24T10:08:40.9...
# ...

# %%
#Columnas
planning_2021_df.columns
# Out:
# Index(['ocid', 'id', 'rationale', 'budget_id', 'budget_description',
#        'budget_amount', 'budget_currency'],
#       dtype='object')

# %%
planning_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38204 entries, 0 to 38203
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ocid                38204 non-null  object
#  1   id                  38204 non-null  object
#  2   rationale           38203 non-null  object
#  3   budget_id           38204 non-null  object
#  4   budget_description  0 non-null      float64
#  5   budget_amount       18463 non-null  float64
#  6   budget_currency     18463 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ### releases_2021.csv

# %%
releases_2021_df = pd.read_csv(os.path.join(datas_dir,datasa_2021[5]),sep=",")
releases_2021_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-SIE-EPMFCR-2021-001A-877354  \
# 1   ocds-5wno2w-SIE-EPP-2020849-21.-253178
# 2  ocds-5wno2w-SIE-EPP-2021000-1-21-253178
# 3    ocds-5wno2w-SIE-EPP-2021048-21-253178
# 4    ocds-5wno2w-SIE-EPP-2021064-21-253178
# 5    ocds-5wno2w-SIE-EPP-2021054-21-253178
# 6    ocds-5wno2w-SIE-GADMCU-2021-006-72903
# 7     ocds-5wno2w-SIE-NDSM-015-2021-185868
# 8    ocds-5wno2w-MCO-GADC-1643UE-1221-2616
# 9    ocds-5wno2w-MCO-GADC-1646UE-1221-2616
#
#                                                   id initiationType
# 0  SIE-EPMFCR-2021-001A-877354-2022-02-24T10:16:4...         tender  \
# 1  SIE-EPP-2020849-21.-253178-2022-10-13T18:32:47...         tender
# 2  SIE-EPP-2021000-1-21-253178-2022-04-07T11:20:3...         tender
# 3  SIE-EPP-2021048-21-253178-2022-06-30T13:04:34....         tender
# 4  SIE-EPP-2021064-21-253178-2022-03-19T11:20:40....         tender
# 5  SIE-EPP-2021054-21-253178-2022-06-14T12:30:22....         tender
# ...

# %%
#Columnas
releases_2021_df.columns
# Out:
# Index(['ocid', 'id', 'initiationType', 'buyer_id', 'buyer_name', 'language',
#        'date', 'tag'],
#       dtype='object')

# %%
releases_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167058 entries, 0 to 167057
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ocid            167058 non-null  object
#  1   id              167058 non-null  object
#  2   initiationType  167058 non-null  object
#  3   buyer_id        167058 non-null  object
#  4   buyer_name      167058 non-null  object
#  5   language        167058 non-null  object
#  6   date            167058 non-null  object
#  7   tag             167058 non-null  object
# dtypes: object(8)
# memory usage: 10.2+ MB

# %% [markdown]
# ### suppliers_2021.csv

# %%
suppliers_2021_df = pd.read_csv(os.path.join(datas_dir,datasa_2021[6]),sep=",")
suppliers_2021_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-SIE-EPMFCR-2021-001A-877354  \
# 1   ocds-5wno2w-SIE-EPP-2020849-21.-253178
# 2  ocds-5wno2w-SIE-EPP-2021000-1-21-253178
# 3    ocds-5wno2w-SIE-EPP-2021048-21-253178
# 4    ocds-5wno2w-SIE-EPP-2021064-21-253178
# 5    ocds-5wno2w-SIE-EPP-2021054-21-253178
# 6    ocds-5wno2w-SIE-GADMCU-2021-006-72903
# 7     ocds-5wno2w-SIE-NDSM-015-2021-185868
# 8    ocds-5wno2w-MCO-GADC-1643UE-1221-2616
# 9    ocds-5wno2w-MCO-GADC-1646UE-1221-2616
#
#                                           release_id
# 0  SIE-EPMFCR-2021-001A-877354-2022-02-24T10:16:4...  \
# 1  SIE-EPP-2020849-21.-253178-2022-10-13T18:32:47...
# 2  SIE-EPP-2021000-1-21-253178-2022-04-07T11:20:3...
# 3  SIE-EPP-2021048-21-253178-2022-06-30T13:04:34....
# 4  SIE-EPP-2021064-21-253178-2022-03-19T11:20:40....
# 5  SIE-EPP-2021054-21-253178-2022-06-14T12:30:22....
# 6  SIE-GADMCU-2021-006-72903-2022-02-24T10:07:40....
# 7  SIE-NDSM-015-2021-185868-2022-02-24T10:08:40.9...
# ...

# %%
#Columnas
suppliers_2021_df.columns
# Out:
# Index(['ocid', 'release_id', 'award_id', 'id', 'name'], dtype='object')

# %%
suppliers_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166983 entries, 0 to 166982
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ocid        166983 non-null  object
#  1   release_id  166983 non-null  object
#  2   award_id    166983 non-null  object
#  3   id          166983 non-null  object
#  4   name        166967 non-null  object
# dtypes: object(5)
# memory usage: 6.4+ MB

# %% [markdown]
# ### tender_2021.csv

# %%
tender_2021_df = pd.read_csv(os.path.join(datas_dir,datasa_2021[7]),sep=",")
tender_2021_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_68787/3795986463.py:1: DtypeWarning: Columns (12,13,14,15,16,18,19,20,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   tender_2021_df = pd.read_csv(os.path.join(datas_dir,datasa_2021[7]),sep=",")
#                                       ocid
# 0  ocds-5wno2w-SIE-EPMFCR-2021-001A-877354  \
# 1   ocds-5wno2w-SIE-EPP-2020849-21.-253178
# 2  ocds-5wno2w-SIE-EPP-2021000-1-21-253178
# 3    ocds-5wno2w-SIE-EPP-2021048-21-253178
# 4    ocds-5wno2w-SIE-EPP-2021064-21-253178
# 5    ocds-5wno2w-SIE-EPP-2021054-21-253178
# 6    ocds-5wno2w-SIE-GADMCU-2021-006-72903
# 7     ocds-5wno2w-SIE-NDSM-015-2021-185868
# 8    ocds-5wno2w-MCO-GADC-1643UE-1221-2616
# 9    ocds-5wno2w-MCO-GADC-1646UE-1221-2616
#
#                                           release_id
# 0  SIE-EPMFCR-2021-001A-877354-2022-02-24T10:16:4...  \
# 1  SIE-EPP-2020849-21.-253178-2022-10-13T18:32:47...
# ...

# %%
#Columnas
tender_2021_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status',
#        'procuringEntity_id', 'procuringEntity_name', 'value_amount',
#        'value_currency', 'procurementMethod', 'procurementMethodDetails',
#        'mainProcurementCategory', 'awardCriteria', 'tenderPeriod_startDate',
#        'tenderPeriod_endDate', 'tenderPeriod_maxExtentDate',
#        'tenderPeriod_durationInDays', 'enquiryPeriod_startDate',
#        'enquiryPeriod_endDate', 'enquiryPeriod_maxExtentDate',
#        'enquiryPeriod_durationInDays', 'hasEnquiries', 'eligibilityCriteria',
#        'awardPeriod_startDate', 'awardPeriod_endDate',
#        'awardPeriod_maxExtentDate', 'awardPeriod_durationInDays',
#        'numberOfTenderers'],
#       dtype='object')

# %%
tender_2021_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165616 entries, 0 to 165615
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ocid                          165616 non-null  object
#  1   release_id                    165616 non-null  object
#  2   id                            165616 non-null  object
#  3   title                         165616 non-null  object
#  4   description                   165615 non-null  object
#  5   status                        165616 non-null  object
#  6   procuringEntity_id            165562 non-null  object
#  7   procuringEntity_name          165562 non-null  object
#  8   value_amount                  146566 non-null  float64
#  9   value_currency                146566 non-null  object
#  10  procurementMethod             165616 non-null  object
#  11  procurementMethodDetails      165616 non-null  object
# ...
