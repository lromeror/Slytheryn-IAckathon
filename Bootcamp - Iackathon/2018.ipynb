# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2018

# %%
datasa_2018=["awards_2018.csv","contracts_2018.csv","extensions_2018.csv","metadata_2018.csv","planning_2018.csv","releases_2018.csv","suppliers_2018.csv","tender_2018.csv"]
datas_dir ="assets/data/releases_2018/"
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### awards_2018.csv

# %%
awards_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[0]),sep=",")
awards_2018_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_67301/2163740379.py:1: DtypeWarning: Columns (4,5,6,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   awards_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[0]),sep=",")
#                                       ocid
# 0       ocds-5wno2w-MCO-GADMA-21-2018-2161  \
# 1      ocds-5wno2w-SIE-008-HMHP-2018-11080
# 2  ocds-5wno2w-SIE-CONAFIPS-03-2018-448191
# 3   ocds-5wno2w-SIE-EPP-2016233-018-253178
# 4  ocds-5wno2w-SIE-EPP-674Y678-1-18-253178
# 5     ocds-5wno2w-MCO-0005-CBB-2018-498171
# 6    ocds-5wno2w-MCO-003-GADMSL-2018-86907
# 7   ocds-5wno2w-MCO-003-GADPCH-2018-114173
# 8       ocds-5wno2w-MCO-GADMA-14-2018-2161
# 9       ocds-5wno2w-MCO-GADMA-22-2018-2161
#
#                                           release_id
# 0    MCO-GADMA-21-2018-2161-2021-12-01T13:39:36.681Z  \
# 1   SIE-008-HMHP-2018-11080-2021-12-01T10:46:59.676Z
# 2  SIE-CONAFIPS-03-2018-448191-2021-12-01T14:09:0...
# ...

# %%
#Columnas 
awards_2018_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status', 'date',
#        'amount', 'currency', 'correctedValue_amount',
#        'correctedValue_currency', 'enteredValue_amount',
#        'enteredValue_currency', 'contractPeriod_startDate',
#        'contractPeriod_endDate', 'contractPeriod_maxExtentDate',
#        'contractPeriod_durationInDays'],
#       dtype='object')

# %%
awards_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359639 entries, 0 to 359638
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           359639 non-null  object
#  1   release_id                     359639 non-null  object
#  2   id                             359639 non-null  object
#  3   title                          0 non-null       float64
#  4   description                    48973 non-null   object
#  5   status                         310659 non-null  object
#  6   date                           38871 non-null   object
#  7   amount                         359635 non-null  float64
#  8   currency                       359636 non-null  object
#  9   correctedValue_amount          0 non-null       float64
#  10  correctedValue_currency        0 non-null       float64
#  11  enteredValue_amount            0 non-null       float64
# ...

# %% [markdown]
# ### contracts_2018.csv

# %%
contracts_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[1]),sep=",")
contracts_2018_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_67301/425971512.py:1: DtypeWarning: Columns (7,8,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   contracts_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[1]),sep=",")
#                                       ocid
# 0      ocds-5wno2w-SIE-008-HMHP-2018-11080  \
# 1  ocds-5wno2w-SIE-CONAFIPS-03-2018-448191
# 2   ocds-5wno2w-SIE-EPP-2016233-018-253178
# 3  ocds-5wno2w-SIE-EPP-674Y678-1-18-253178
# 4     ocds-5wno2w-RE-HEJCA-F-66-2018-87497
# 5   ocds-5wno2w-RE-PU-D17D05-002-201-70367
# 6      ocds-5wno2w-SIE-CELTES-67-18-240719
# 7    ocds-5wno2w-SIE-DD13D02-2018-08-18162
# 8    ocds-5wno2w-SIE-DD13D02-2018-09-18162
# 9   ocds-5wno2w-SIE-EECS-DC-121-2018-56835
#
#                                           release_id
# 0   SIE-008-HMHP-2018-11080-2021-12-01T10:46:59.676Z  \
# 1  SIE-CONAFIPS-03-2018-448191-2021-12-01T14:09:0...
# 2  SIE-EPP-2016233-018-253178-2021-12-01T14:13:47...
# ...

# %%
#Columnas
contracts_2018_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348034 entries, 0 to 348033
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           348034 non-null  object
#  1   release_id                     348034 non-null  object
#  2   id                             348034 non-null  object
#  3   awardID                        348034 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         348034 non-null  object
#  7   contractPeriod_startDate       37371 non-null   object
#  8   contractPeriod_endDate         37371 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  37319 non-null   float64
#  11  amount                         37371 non-null   float64
# ...

# %% [markdown]
# ### extensions_2018.csv

# %%
extensions_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[2]),sep=",")
extensions_2018_df.head(10)
# Out:
#                                            extension
# 0  https://raw.githubusercontent.com/open-contrac...
# 1  https://raw.githubusercontent.com/open-contrac...
# 2  https://raw.githubusercontent.com/open-contrac...
# 3  https://raw.githubusercontent.com/GobiernoFaci...
# 4  https://gitlab.com/dncp-opendata/ocds_auctions...
# 5  https://raw.githubusercontent.com/open-contrac...
# 6  https://raw.githubusercontent.com/open-contrac...

# %%
#Columnas
contracts_2018_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348034 entries, 0 to 348033
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           348034 non-null  object
#  1   release_id                     348034 non-null  object
#  2   id                             348034 non-null  object
#  3   awardID                        348034 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         348034 non-null  object
#  7   contractPeriod_startDate       37371 non-null   object
#  8   contractPeriod_endDate         37371 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  37319 non-null   float64
#  11  amount                         37371 non-null   float64
# ...

# %% [markdown]
# ### metadata_2018.csv

# %%
metadata_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[3]),sep=",")
metadata_2018_df.head(10)
# Out:
#                                                  Uri  Version
# 0  https://portal.compraspublicas.gob.ec/sercop/d...      1.1  \
#
#                                        PublisherName PublisherScheme
# 0  Servicio Nacional de Contratación Pública (SER...            OCDS  \
#
#   PublisherUid                        PublisherUri
# 0  ocds-5wno2w  https://www.compraspublicas.gob.ec  \
#
#                                            License
# 0  https://creativecommons.org/licenses/by/3.0/ec/  \
#
#                                    PublicationPolicy             PublishedDate
# 0  https://datosabiertos.compraspublicas.gob.ec/P...  2021-12-03T05:39:29.183Z

# %%
#Columnas
metadata_2018_df.columns
# Out:
# Index(['Uri', 'Version', 'PublisherName', 'PublisherScheme', 'PublisherUid',
#        'PublisherUri', 'License', 'PublicationPolicy', 'PublishedDate'],
#       dtype='object')

# %% [markdown]
# ### planning_2018.csv

# %%
planning_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[4]),sep=",")
planning_2018_df.head(10)
# Out:
#                                       ocid
# 0       ocds-5wno2w-MCO-GADMA-21-2018-2161  \
# 1      ocds-5wno2w-SIE-008-HMHP-2018-11080
# 2  ocds-5wno2w-SIE-CONAFIPS-03-2018-448191
# 3   ocds-5wno2w-SIE-EPP-2016233-018-253178
# 4  ocds-5wno2w-SIE-EPP-674Y678-1-18-253178
# 5     ocds-5wno2w-MCO-0005-CBB-2018-498171
# 6    ocds-5wno2w-MCO-003-GADMSL-2018-86907
# 7   ocds-5wno2w-MCO-003-GADPCH-2018-114173
# 8       ocds-5wno2w-MCO-GADMA-14-2018-2161
# 9       ocds-5wno2w-MCO-GADMA-22-2018-2161
#
#                                                   id
# 0    MCO-GADMA-21-2018-2161-2021-12-01T13:39:36.681Z  \
# 1   SIE-008-HMHP-2018-11080-2021-12-01T10:46:59.676Z
# 2  SIE-CONAFIPS-03-2018-448191-2021-12-01T14:09:0...
# 3  SIE-EPP-2016233-018-253178-2021-12-01T14:13:47...
# 4  SIE-EPP-674Y678-1-18-253178-2021-12-01T14:46:3...
# 5  MCO-0005-CBB-2018-498171-2021-12-01T10:56:32.843Z
# 6  MCO-003-GADMSL-2018-86907-2021-12-01T16:29:47....
# 7  MCO-003-GADPCH-2018-114173-2021-12-01T16:18:10...
# ...

# %%
#Columnas
planning_2018_df.columns
# Out:
# Index(['ocid', 'id', 'rationale', 'budget_id', 'budget_description',
#        'budget_amount', 'budget_currency'],
#       dtype='object')

# %%
planning_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47028 entries, 0 to 47027
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ocid                47028 non-null  object
#  1   id                  47028 non-null  object
#  2   rationale           47028 non-null  object
#  3   budget_id           47028 non-null  object
#  4   budget_description  0 non-null      float64
#  5   budget_amount       26210 non-null  float64
#  6   budget_currency     26210 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 2.5+ MB

# %% [markdown]
# ### releases_2018.csv

# %%
releases_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[5]),sep=",")
releases_2018_df.head(10)
# Out:
#                                       ocid
# 0       ocds-5wno2w-MCO-GADMA-21-2018-2161  \
# 1      ocds-5wno2w-SIE-008-HMHP-2018-11080
# 2  ocds-5wno2w-SIE-CONAFIPS-03-2018-448191
# 3   ocds-5wno2w-SIE-EPP-2016233-018-253178
# 4  ocds-5wno2w-SIE-EPP-674Y678-1-18-253178
# 5     ocds-5wno2w-MCO-0005-CBB-2018-498171
# 6    ocds-5wno2w-MCO-003-GADMSL-2018-86907
# 7   ocds-5wno2w-MCO-003-GADPCH-2018-114173
# 8       ocds-5wno2w-MCO-GADMA-14-2018-2161
# 9       ocds-5wno2w-MCO-GADMA-22-2018-2161
#
#                                                   id initiationType
# 0    MCO-GADMA-21-2018-2161-2021-12-01T13:39:36.681Z         tender  \
# 1   SIE-008-HMHP-2018-11080-2021-12-01T10:46:59.676Z         tender
# 2  SIE-CONAFIPS-03-2018-448191-2021-12-01T14:09:0...         tender
# 3  SIE-EPP-2016233-018-253178-2021-12-01T14:13:47...         tender
# 4  SIE-EPP-674Y678-1-18-253178-2021-12-01T14:46:3...         tender
# 5  MCO-0005-CBB-2018-498171-2021-12-01T10:56:32.843Z         tender
# ...

# %%
#Columnas
releases_2018_df.columns
# Out:
# Index(['ocid', 'id', 'initiationType', 'buyer_id', 'buyer_name', 'language',
#        'date', 'tag'],
#       dtype='object')

# %%
releases_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357687 entries, 0 to 357686
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ocid            357687 non-null  object
#  1   id              357687 non-null  object
#  2   initiationType  357687 non-null  object
#  3   buyer_id        357687 non-null  object
#  4   buyer_name      357687 non-null  object
#  5   language        357687 non-null  object
#  6   date            357687 non-null  object
#  7   tag             357687 non-null  object
# dtypes: object(8)
# memory usage: 21.8+ MB

# %% [markdown]
# ### suppliers_2018.csv

# %%
suppliers_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[6]),sep=",")
suppliers_2018_df.head(10)
# Out:
#                                       ocid
# 0       ocds-5wno2w-MCO-GADMA-21-2018-2161  \
# 1      ocds-5wno2w-SIE-008-HMHP-2018-11080
# 2  ocds-5wno2w-SIE-CONAFIPS-03-2018-448191
# 3   ocds-5wno2w-SIE-EPP-2016233-018-253178
# 4  ocds-5wno2w-SIE-EPP-674Y678-1-18-253178
# 5     ocds-5wno2w-MCO-0005-CBB-2018-498171
# 6    ocds-5wno2w-MCO-003-GADMSL-2018-86907
# 7   ocds-5wno2w-MCO-003-GADPCH-2018-114173
# 8       ocds-5wno2w-MCO-GADMA-14-2018-2161
# 9       ocds-5wno2w-MCO-GADMA-22-2018-2161
#
#                                           release_id
# 0    MCO-GADMA-21-2018-2161-2021-12-01T13:39:36.681Z  \
# 1   SIE-008-HMHP-2018-11080-2021-12-01T10:46:59.676Z
# 2  SIE-CONAFIPS-03-2018-448191-2021-12-01T14:09:0...
# 3  SIE-EPP-2016233-018-253178-2021-12-01T14:13:47...
# 4  SIE-EPP-674Y678-1-18-253178-2021-12-01T14:46:3...
# 5  MCO-0005-CBB-2018-498171-2021-12-01T10:56:32.843Z
# 6  MCO-003-GADMSL-2018-86907-2021-12-01T16:29:47....
# 7  MCO-003-GADPCH-2018-114173-2021-12-01T16:18:10...
# ...

# %%
#Columnas
suppliers_2018_df.columns
# Out:
# Index(['ocid', 'release_id', 'award_id', 'id', 'name'], dtype='object')

# %%
suppliers_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359637 entries, 0 to 359636
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ocid        359637 non-null  object
#  1   release_id  359637 non-null  object
#  2   award_id    359637 non-null  object
#  3   id          359637 non-null  object
#  4   name        359634 non-null  object
# dtypes: object(5)
# memory usage: 13.7+ MB

# %% [markdown]
# ### tender_2018.csv

# %%
tender_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[7]),sep=",")
tender_2018_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_67301/2424042470.py:1: DtypeWarning: Columns (12,13,14,15,16,18,19,20,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   tender_2018_df = pd.read_csv(os.path.join(datas_dir,datasa_2018[7]),sep=",")
#                                       ocid
# 0       ocds-5wno2w-MCO-GADMA-21-2018-2161  \
# 1      ocds-5wno2w-SIE-008-HMHP-2018-11080
# 2  ocds-5wno2w-SIE-CONAFIPS-03-2018-448191
# 3   ocds-5wno2w-SIE-EPP-2016233-018-253178
# 4  ocds-5wno2w-SIE-EPP-674Y678-1-18-253178
# 5     ocds-5wno2w-MCO-0005-CBB-2018-498171
# 6    ocds-5wno2w-MCO-003-GADMSL-2018-86907
# 7   ocds-5wno2w-MCO-003-GADPCH-2018-114173
# 8       ocds-5wno2w-MCO-GADMA-14-2018-2161
# 9       ocds-5wno2w-MCO-GADMA-22-2018-2161
#
#                                           release_id
# 0    MCO-GADMA-21-2018-2161-2021-12-01T13:39:36.681Z  \
# 1   SIE-008-HMHP-2018-11080-2021-12-01T10:46:59.676Z
# ...

# %%
#Columnas
tender_2018_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status',
#        'procuringEntity_id', 'procuringEntity_name', 'value_amount',
#        'value_currency', 'procurementMethod', 'procurementMethodDetails',
#        'mainProcurementCategory', 'awardCriteria', 'tenderPeriod_startDate',
#        'tenderPeriod_endDate', 'tenderPeriod_maxExtentDate',
#        'tenderPeriod_durationInDays', 'enquiryPeriod_startDate',
#        'enquiryPeriod_endDate', 'enquiryPeriod_maxExtentDate',
#        'enquiryPeriod_durationInDays', 'hasEnquiries', 'eligibilityCriteria',
#        'awardPeriod_startDate', 'awardPeriod_endDate',
#        'awardPeriod_maxExtentDate', 'awardPeriod_durationInDays',
#        'numberOfTenderers'],
#       dtype='object')

# %%
tender_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357687 entries, 0 to 357686
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ocid                          357687 non-null  object
#  1   release_id                    357687 non-null  object
#  2   id                            357687 non-null  object
#  3   title                         357687 non-null  object
#  4   description                   357687 non-null  object
#  5   status                        357687 non-null  object
#  6   procuringEntity_id            357687 non-null  object
#  7   procuringEntity_name          357687 non-null  object
#  8   value_amount                  336868 non-null  float64
#  9   value_currency                336869 non-null  object
#  10  procurementMethod             357687 non-null  object
#  11  procurementMethodDetails      357687 non-null  object
# ...
