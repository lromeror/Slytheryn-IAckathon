# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2019

# %%
datasa_2019=["awards_2019.csv","contracts_2019.csv","extensions_2019.csv","metadata_2019.csv","planning_2019.csv","releases_2019.csv","suppliers_2019.csv","tender_2019.csv"]
datas_dir ="assets/data/releases_2019/"
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### awards_2019.csv

# %%
awards_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[0]),sep=",")
awards_2019_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_67661/1555206487.py:1: DtypeWarning: Columns (4,6,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   awards_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[0]),sep=",")
#                                       ocid
# 0  ocds-5wno2w-CDC-EMUCEEP-005-2019-289014  \
# 1     ocds-5wno2w-CE-20190001488077-224957
# 2     ocds-5wno2w-CE-20190001515826-224957
# 3     ocds-5wno2w-CE-20190001515827-224957
# 4     ocds-5wno2w-CE-20190001515829-224957
# 5     ocds-5wno2w-CE-20190001515830-224957
# 6     ocds-5wno2w-CE-20190001515831-224957
# 7     ocds-5wno2w-CE-20190001515832-224957
# 8     ocds-5wno2w-CE-20190001515833-224957
# 9     ocds-5wno2w-CE-20190001515834-224957
#
#                                           release_id
# 0  CDC-EMUCEEP-005-2019-289014-2021-12-01T04:09:2...  \
# 1  CE-20190001488077-224957-2021-11-29T23:13:04.385Z
# 2  CE-20190001515826-224957-2021-11-29T23:38:29.506Z
# ...

# %%
#Columnas 
awards_2019_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status', 'date',
#        'amount', 'currency', 'correctedValue_amount',
#        'correctedValue_currency', 'enteredValue_amount',
#        'enteredValue_currency', 'contractPeriod_startDate',
#        'contractPeriod_endDate', 'contractPeriod_maxExtentDate',
#        'contractPeriod_durationInDays'],
#       dtype='object')

# %%
awards_2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277117 entries, 0 to 277116
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           277117 non-null  object
#  1   release_id                     277117 non-null  object
#  2   id                             277117 non-null  object
#  3   title                          0 non-null       float64
#  4   description                    40712 non-null   object
#  5   status                         236394 non-null  object
#  6   date                           33769 non-null   object
#  7   amount                         277115 non-null  float64
#  8   currency                       277116 non-null  object
#  9   correctedValue_amount          0 non-null       float64
#  10  correctedValue_currency        0 non-null       float64
#  11  enteredValue_amount            0 non-null       float64
# ...

# %% [markdown]
# ### contracts_2019.csv

# %%
contracts_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[1]),sep=",")
contracts_2019_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_67661/3587108646.py:1: DtypeWarning: Columns (7,8,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   contracts_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[1]),sep=",")
#                                       ocid
# 0  ocds-5wno2w-CDC-EMUCEEP-005-2019-289014  \
# 1     ocds-5wno2w-CE-20190001488077-224957
# 2     ocds-5wno2w-CE-20190001515826-224957
# 3     ocds-5wno2w-CE-20190001515827-224957
# 4     ocds-5wno2w-CE-20190001515829-224957
# 5     ocds-5wno2w-CE-20190001515830-224957
# 6     ocds-5wno2w-CE-20190001515831-224957
# 7     ocds-5wno2w-CE-20190001515832-224957
# 8     ocds-5wno2w-CE-20190001515833-224957
# 9     ocds-5wno2w-CE-20190001515834-224957
#
#                                           release_id
# 0  CDC-EMUCEEP-005-2019-289014-2021-12-01T04:09:2...  \
# 1  CE-20190001488077-224957-2021-11-29T23:13:04.385Z
# 2  CE-20190001515826-224957-2021-11-29T23:38:29.506Z
# ...

# %%
#Columnas
contracts_2019_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268312 entries, 0 to 268311
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           268312 non-null  object
#  1   release_id                     268312 non-null  object
#  2   id                             268312 non-null  object
#  3   awardID                        268312 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         268312 non-null  object
#  7   contractPeriod_startDate       31913 non-null   object
#  8   contractPeriod_endDate         31913 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  31880 non-null   float64
#  11  amount                         31913 non-null   float64
# ...

# %% [markdown]
# ### extensions_2019.csv

# %%
extensions_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[2]),sep=",")
extensions_2019_df.head(10)
# Out:
#                                            extension
# 0  https://raw.githubusercontent.com/open-contrac...
# 1  https://raw.githubusercontent.com/open-contrac...
# 2  https://raw.githubusercontent.com/open-contrac...
# 3  https://raw.githubusercontent.com/GobiernoFaci...
# 4  https://gitlab.com/dncp-opendata/ocds_auctions...
# 5  https://raw.githubusercontent.com/open-contrac...
# 6  https://raw.githubusercontent.com/open-contrac...

# %%
#Columnas
contracts_2019_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'awardID', 'title', 'description', 'status',
#        'contractPeriod_startDate', 'contractPeriod_endDate',
#        'contractPeriod_maxExtentDate', 'contractPeriod_durationInDays',
#        'amount', 'currency', 'dateSigned'],
#       dtype='object')

# %%
contracts_2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268312 entries, 0 to 268311
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ocid                           268312 non-null  object
#  1   release_id                     268312 non-null  object
#  2   id                             268312 non-null  object
#  3   awardID                        268312 non-null  object
#  4   title                          0 non-null       float64
#  5   description                    0 non-null       float64
#  6   status                         268312 non-null  object
#  7   contractPeriod_startDate       31913 non-null   object
#  8   contractPeriod_endDate         31913 non-null   object
#  9   contractPeriod_maxExtentDate   0 non-null       float64
#  10  contractPeriod_durationInDays  31880 non-null   float64
#  11  amount                         31913 non-null   float64
# ...

# %% [markdown]
# ### metadata_2019.csv

# %%
metadata_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[3]),sep=",")
metadata_2019_df.head(10)
# Out:
#                                                  Uri  Version
# 0  https://portal.compraspublicas.gob.ec/sercop/d...      1.1  \
#
#                                        PublisherName PublisherScheme
# 0  Servicio Nacional de Contratación Pública (SER...            OCDS  \
#
#   PublisherUid                        PublisherUri
# 0  ocds-5wno2w  https://www.compraspublicas.gob.ec  \
#
#                                            License
# 0  https://creativecommons.org/licenses/by/3.0/ec/  \
#
#                                    PublicationPolicy             PublishedDate
# 0  https://datosabiertos.compraspublicas.gob.ec/P...  2021-12-03T05:39:29.183Z

# %%
#Columnas
metadata_2019_df.columns
# Out:
# Index(['Uri', 'Version', 'PublisherName', 'PublisherScheme', 'PublisherUid',
#        'PublisherUri', 'License', 'PublicationPolicy', 'PublishedDate'],
#       dtype='object')

# %% [markdown]
# ### planning_2019.csv

# %%
planning_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[4]),sep=",")
planning_2019_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-CDC-EMUCEEP-005-2019-289014  \
# 1   ocds-5wno2w-COTO-GADPRP-2019-001-98128
# 2    ocds-5wno2w-MCO-CARCHI-011P-2019-2481
# 3    ocds-5wno2w-MCO-GADMCL-2019-005-32457
# 4       ocds-5wno2w-MCO-GPI-013-2019-12001
# 5       ocds-5wno2w-MCO-IMSE-005-2019-4081
# 6    ocds-5wno2w-RE-EECS-DF-011-2019-56835
# 7     ocds-5wno2w-RE-EENORTE-017-2019-3243
# 8  ocds-5wno2w-CDC-EMUCEEP-006-2019-289014
# 9    ocds-5wno2w-LICOB-EEQ-GD005-2019-3214
#
#                                                   id
# 0  CDC-EMUCEEP-005-2019-289014-2021-12-01T04:09:2...  \
# 1  COTO-GADPRP-2019-001-98128-2021-12-01T06:58:07...
# 2  MCO-CARCHI-011P-2019-2481-2021-12-01T04:14:40....
# 3  MCO-GADMCL-2019-005-32457-2021-12-01T06:59:13....
# 4    MCO-GPI-013-2019-12001-2021-12-01T03:48:48.347Z
# 5    MCO-IMSE-005-2019-4081-2021-12-01T06:39:36.804Z
# 6  RE-EECS-DF-011-2019-56835-2021-12-01T03:53:01....
# 7  RE-EENORTE-017-2019-3243-2021-12-01T05:39:26.018Z
# ...

# %%
#Columnas
planning_2019_df.columns
# Out:
# Index(['ocid', 'id', 'rationale', 'budget_id', 'budget_description',
#        'budget_amount', 'budget_currency'],
#       dtype='object')

# %%
planning_2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38661 entries, 0 to 38660
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ocid                38661 non-null  object
#  1   id                  38661 non-null  object
#  2   rationale           38661 non-null  object
#  3   budget_id           38661 non-null  object
#  4   budget_description  0 non-null      float64
#  5   budget_amount       19851 non-null  float64
#  6   budget_currency     19851 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 2.1+ MB

# %% [markdown]
# ### releases_2019.csv

# %%
releases_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[5]),sep=",")
releases_2019_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-CDC-EMUCEEP-005-2019-289014  \
# 1     ocds-5wno2w-CE-20190001488077-224957
# 2     ocds-5wno2w-CE-20190001515826-224957
# 3     ocds-5wno2w-CE-20190001515827-224957
# 4     ocds-5wno2w-CE-20190001515829-224957
# 5     ocds-5wno2w-CE-20190001515830-224957
# 6     ocds-5wno2w-CE-20190001515831-224957
# 7     ocds-5wno2w-CE-20190001515832-224957
# 8     ocds-5wno2w-CE-20190001515833-224957
# 9     ocds-5wno2w-CE-20190001515834-224957
#
#                                                   id initiationType
# 0  CDC-EMUCEEP-005-2019-289014-2021-12-01T04:09:2...         tender  \
# 1  CE-20190001488077-224957-2021-11-29T23:13:04.385Z         tender
# 2  CE-20190001515826-224957-2021-11-29T23:38:29.506Z         tender
# 3  CE-20190001515827-224957-2021-11-29T23:38:29.533Z         tender
# 4  CE-20190001515829-224957-2021-11-29T23:38:29.550Z         tender
# 5  CE-20190001515830-224957-2021-11-29T23:38:29.575Z         tender
# ...

# %%
#Columnas
releases_2019_df.columns
# Out:
# Index(['ocid', 'id', 'initiationType', 'buyer_id', 'buyer_name', 'language',
#        'date', 'tag'],
#       dtype='object')

# %%
releases_2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275055 entries, 0 to 275054
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ocid            275055 non-null  object
#  1   id              275055 non-null  object
#  2   initiationType  275055 non-null  object
#  3   buyer_id        275055 non-null  object
#  4   buyer_name      275055 non-null  object
#  5   language        275055 non-null  object
#  6   date            275055 non-null  object
#  7   tag             275055 non-null  object
# dtypes: object(8)
# memory usage: 16.8+ MB

# %% [markdown]
# ### suppliers_2019.csv

# %%
suppliers_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[6]),sep=",")
suppliers_2019_df.head(10)
# Out:
#                                       ocid
# 0  ocds-5wno2w-CDC-EMUCEEP-005-2019-289014  \
# 1     ocds-5wno2w-CE-20190001488077-224957
# 2     ocds-5wno2w-CE-20190001515826-224957
# 3     ocds-5wno2w-CE-20190001515827-224957
# 4     ocds-5wno2w-CE-20190001515829-224957
# 5     ocds-5wno2w-CE-20190001515830-224957
# 6     ocds-5wno2w-CE-20190001515831-224957
# 7     ocds-5wno2w-CE-20190001515832-224957
# 8     ocds-5wno2w-CE-20190001515833-224957
# 9     ocds-5wno2w-CE-20190001515834-224957
#
#                                           release_id
# 0  CDC-EMUCEEP-005-2019-289014-2021-12-01T04:09:2...  \
# 1  CE-20190001488077-224957-2021-11-29T23:13:04.385Z
# 2  CE-20190001515826-224957-2021-11-29T23:38:29.506Z
# 3  CE-20190001515827-224957-2021-11-29T23:38:29.533Z
# 4  CE-20190001515829-224957-2021-11-29T23:38:29.550Z
# 5  CE-20190001515830-224957-2021-11-29T23:38:29.575Z
# 6  CE-20190001515831-224957-2021-11-29T23:38:29.592Z
# 7  CE-20190001515832-224957-2021-11-29T23:38:29.612Z
# ...

# %%
#Columnas
suppliers_2019_df.columns
# Out:
# Index(['ocid', 'release_id', 'award_id', 'id', 'name'], dtype='object')

# %%
suppliers_2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277117 entries, 0 to 277116
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ocid        277117 non-null  object
#  1   release_id  277117 non-null  object
#  2   award_id    277117 non-null  object
#  3   id          277117 non-null  object
#  4   name        277111 non-null  object
# dtypes: object(5)
# memory usage: 10.6+ MB

# %% [markdown]
# ### tender_2019.csv

# %%
tender_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[7]),sep=",")
tender_2019_df.head(10)
# Out:
# /var/folders/pf/565wgnj55rl181qjmrmqq69m0000gn/T/ipykernel_67661/104917942.py:1: DtypeWarning: Columns (12,13,14,15,16,18,19,20,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   tender_2019_df = pd.read_csv(os.path.join(datas_dir,datasa_2019[7]),sep=",")
#                                       ocid
# 0  ocds-5wno2w-CDC-EMUCEEP-005-2019-289014  \
# 1     ocds-5wno2w-CE-20190001488077-224957
# 2     ocds-5wno2w-CE-20190001515826-224957
# 3     ocds-5wno2w-CE-20190001515827-224957
# 4     ocds-5wno2w-CE-20190001515829-224957
# 5     ocds-5wno2w-CE-20190001515830-224957
# 6     ocds-5wno2w-CE-20190001515831-224957
# 7     ocds-5wno2w-CE-20190001515832-224957
# 8     ocds-5wno2w-CE-20190001515833-224957
# 9     ocds-5wno2w-CE-20190001515834-224957
#
#                                           release_id
# 0  CDC-EMUCEEP-005-2019-289014-2021-12-01T04:09:2...  \
# 1  CE-20190001488077-224957-2021-11-29T23:13:04.385Z
# ...

# %%
#Columnas
tender_2019_df.columns
# Out:
# Index(['ocid', 'release_id', 'id', 'title', 'description', 'status',
#        'procuringEntity_id', 'procuringEntity_name', 'value_amount',
#        'value_currency', 'procurementMethod', 'procurementMethodDetails',
#        'mainProcurementCategory', 'awardCriteria', 'tenderPeriod_startDate',
#        'tenderPeriod_endDate', 'tenderPeriod_maxExtentDate',
#        'tenderPeriod_durationInDays', 'enquiryPeriod_startDate',
#        'enquiryPeriod_endDate', 'enquiryPeriod_maxExtentDate',
#        'enquiryPeriod_durationInDays', 'hasEnquiries', 'eligibilityCriteria',
#        'awardPeriod_startDate', 'awardPeriod_endDate',
#        'awardPeriod_maxExtentDate', 'awardPeriod_durationInDays',
#        'numberOfTenderers'],
#       dtype='object')

# %%
tender_2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275055 entries, 0 to 275054
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ocid                          275055 non-null  object
#  1   release_id                    275055 non-null  object
#  2   id                            275055 non-null  object
#  3   title                         275055 non-null  object
#  4   description                   275055 non-null  object
#  5   status                        275055 non-null  object
#  6   procuringEntity_id            275055 non-null  object
#  7   procuringEntity_name          275055 non-null  object
#  8   value_amount                  256244 non-null  float64
#  9   value_currency                256245 non-null  object
#  10  procurementMethod             275055 non-null  object
#  11  procurementMethodDetails      275055 non-null  object
# ...
